# %%
import numpy as np
import pandas as pd
import re
import string
import matplotlib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier,RidgeClassifier,PassiveAggressiveClassifier
import pickle
from sklearn.metrics import precision_recall_fscore_support,accuracy_score
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
from datetime import datetime
import matplotlib.pyplot as plt
from pandas_ml import ConfusionMatrix 
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix 
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import collections as ct
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords

# %%
input_df = pd.read_csv('incident_1month_resolved.csv')
print(input_df.shape)
# Out:
# (22363, 42)

# %%
special_chars = string.punctuation  
stop = stopwords.words('english')
from datetime import datetime

def junk_clean(text):
    
#     starttime = datetime.now()
#     tagged = ne_chunk(pos_tag(word_tokenize(text)))
#     person = []
#     for subtree in tagged.subtrees(filter=lambda t: t.label() == 'PERSON'):
#         for leaf in subtree.leaves():
#             person.append(leaf[0])
#     print("Person Tagging: " + (datetime.now() - starttime))
    
    starttime1 = datetime.now()
    junk = []
    body = []
    b = text.splitlines()
    for index, i in enumerate(b):
        c = i.split()
        if len(c) > 0:
            sp = sum(v for k, v in ct.Counter(i).items() if k in special_chars)/len(c)
            #name_perc = len(list(set(c).intersection(person)))/len(c)
            stop_perc = len(list(set(c).intersection(stop)))/len(c)
            if len(c) < 10  or sp >= 0.5 or stop_perc <= 0.05:
                junk.append(i)
                #print(index, "\t", "%.2f" % name_perc, "\t",len(c),"\t","%.2f" % sp ,"\t","%.2f" % stop_perc, "\t", i)
            else:
                body.append(i)
        else:
            continue
            
    #print("Person Tagging: %s" % (datetime.now() - starttime1))
    
    junk = '\n'.join(junk)
    body = '\n'.join(body)
    return pd.Series({'junk': junk, 'body': body})

# %%
new = input_df["Symptom"].apply(junk_clean)
temp = pd.concat([input_df, new], axis=1)
sum(temp["body"]!="")
# Out:
# 18525

# %%
import re
from datetime import datetime
import itertools
def countTotal(ser,vecs):
    print(len(vecs))
    total = 0;
    for vec in vecs:
        a = ser.str.contains(vec).sum()
        print(a)
        #print(ser)
        #print(ser.str.contains("original"))
        total += a
    print("Total occurances - %d" %total)
    
def parse_text(text):
    for pattern, replacement in new_dict_comp.items():
        text = pattern.sub(replacement, text)
    return text

i = 50;
startTime1 = datetime.now()
temp["New_Symptom"] = temp["body"];
for i in range(300,9,-1):
    for j in range(10,9,-1):
        startTime = datetime.now()
        startTime2 = datetime.now()
        
        print(i , j)
        try:
            pattern = "[\\S]+";
            tf_vectorizer = CountVectorizer( min_df=j,
                                            ngram_range = (i,i),
                                            analyzer='word',
                                            tokenizer=lambda x: x.split(' '),
                                            lowercase = False
                                            )
            tf_vectorizer.fit(temp["New_Symptom"])
            print(tf_vectorizer.get_feature_names())
            print("total vector size - %d" %(len(tf_vectorizer.get_feature_names())))
            
            startTime3 = datetime.now()
            
            a =  zip(tf_vectorizer.get_feature_names(), itertools.repeat(""))
            new_dict = {re.escape(k): v for k, v in a}
            new_dict_comp = {re.compile(k): v for k, v in new_dict.items()}
#             countTotal(input_df["New_Symptom"],tf_vectorizer.get_feature_names())
            temp["New_Symptom"] = temp["New_Symptom"].apply(parse_text)
            
#             for vec in tf_vectorizer.get_feature_names():
#                 #print(input_df["New_Symptom"].str.contains(vec).sum())
#                 input_df["New_Symptom"] = input_df["New_Symptom"].str.replace(re.escape(vec),"")  

            print("time to replace - ")
            print(datetime.now() - startTime3)
            #countTotal(input_df["New_Symptom"],tf_vectorizer.get_feature_names())
#             pattern = "[\\S]+";
#             tf_vectorizer = CountVectorizer( min_df=j,
#                                             ngram_range = (i,i),
#                                             analyzer='word',
#                                             tokenizer=lambda x: x.split(' '),
#                                             lowercase = False
#                                             )
#             tf_vectorizer.fit(temp["New_Symptom"])
#             print("total vector size after replacement - %d" %(len(tf_vectorizer.get_feature_names())))
#             #print(tf_vectorizer.get_feature_names()[0])
#             #input_df["New_Symptom"] = temp
#             print("time to vectorize 2 times- ") 
#             print(datetime.now() - startTime2)
        except ValueError:
            print(ValueError)
        except Exception as e:
            print(e)
        print(datetime.now() - startTime)
print("Total Time: - ")
print(datetime.now() - startTime1)
# Out:
# 300 10
# <class 'ValueError'>
# 0:00:01.144164
# 299 10
# <class 'ValueError'>
# 0:00:01.028341
# 298 10
# <class 'ValueError'>
# 0:00:01.016194
# 297 10
# <class 'ValueError'>
# 0:00:01.025482
# 296 10
# <class 'ValueError'>
# 0:00:01.055598
# 295 10
# <class 'ValueError'>
# 0:00:01.037778
# 294 10
# <class 'ValueError'>
# 0:00:01.041402
# 293 10
# <class 'ValueError'>
# 0:00:01.048541
# 292 10
# <class 'ValueError'>
# 0:00:01.054135
# 291 10
# <class 'ValueError'>
# 0:00:01.070275
# 290 10
# <class 'ValueError'>
# 0:00:01.093569
# 289 10
# <class 'ValueError'>
# 0:00:01.079112
# 288 10
# <class 'ValueError'>
# 0:00:01.054114
# 287 10
# <class 'ValueError'>
# 0:00:01.059776
# 286 10
# <class 'ValueError'>
# 0:00:01.056360
# 285 10
# <class 'ValueError'>
# 0:00:01.063060
# 284 10
# <class 'ValueError'>
# 0:00:01.095099
# 283 10
# <class 'ValueError'>
# 0:00:01.073981
# 282 10
# <class 'ValueError'>
# 0:00:01.061813
# 281 10
# <class 'ValueError'>
# 0:00:01.084048
# 280 10
# <class 'ValueError'>
# 0:00:01.108214
# 279 10
# <class 'ValueError'>
# 0:00:01.100714
# 278 10
# <class 'ValueError'>
# 0:00:01.104725
# 277 10
# <class 'ValueError'>
# 0:00:01.081105
# 276 10
# <class 'ValueError'>
# 0:00:01.104222
# 275 10
# <class 'ValueError'>
# 0:00:01.079990
# 274 10
# <class 'ValueError'>
# 0:00:01.097708
# 273 10
# <class 'ValueError'>
# 0:00:01.103726
# 272 10
# <class 'ValueError'>
# 0:00:01.105222
# 271 10
# <class 'ValueError'>
# 0:00:01.114852
# 270 10
# <class 'ValueError'>
# 0:00:01.110088
# 269 10
# <class 'ValueError'>
# 0:00:01.100162
# 268 10
# <class 'ValueError'>
# 0:00:01.110504
# 267 10
# <class 'ValueError'>
# 0:00:01.126499
# 266 10
# <class 'ValueError'>
# 0:00:01.115475
# 265 10
# <class 'ValueError'>
# 0:00:01.094664
# 264 10
# <class 'ValueError'>
# 0:00:01.116256
# 263 10
# <class 'ValueError'>
# 0:00:01.140385
# 262 10
# <class 'ValueError'>
# 0:00:01.159068
# 261 10
# <class 'ValueError'>
# 0:00:01.160922
# 260 10
# <class 'ValueError'>
# 0:00:01.165852
# 259 10
# <class 'ValueError'>
# 0:00:01.135649
# 258 10
# <class 'ValueError'>
# 0:00:01.159199
# 257 10
# <class 'ValueError'>
# 0:00:01.169571
# 256 10
# <class 'ValueError'>
# 0:00:01.124546
# 255 10
# <class 'ValueError'>
# 0:00:01.124009
# 254 10
# <class 'ValueError'>
# 0:00:01.116628
# 253 10
# <class 'ValueError'>
# 0:00:01.127047
# 252 10
# <class 'ValueError'>
# 0:00:01.133028
# 251 10
# <class 'ValueError'>
# 0:00:01.116375
# 250 10
# <class 'ValueError'>
# 0:00:01.124522
# 249 10
# <class 'ValueError'>
# 0:00:01.125496
# 248 10
# <class 'ValueError'>
# 0:00:01.138481
# 247 10
# <class 'ValueError'>
# 0:00:01.134432
# 246 10
# <class 'ValueError'>
# 0:00:01.141930
# 245 10
# <class 'ValueError'>
# 0:00:01.150008
# 244 10
# <class 'ValueError'>
# 0:00:01.161682
# 243 10
# <class 'ValueError'>
# 0:00:01.141138
# 242 10
# <class 'ValueError'>
# 0:00:01.149731
# 241 10
# <class 'ValueError'>
# 0:00:01.149642
# 240 10
# <class 'ValueError'>
# 0:00:01.149558
# 239 10
# <class 'ValueError'>
# 0:00:01.174194
# 238 10
# <class 'ValueError'>
# 0:00:01.171646
# 237 10
# <class 'ValueError'>
# 0:00:01.163291
# 236 10
# <class 'ValueError'>
# 0:00:01.181747
# 235 10
# <class 'ValueError'>
# 0:00:01.171772
# 234 10
# <class 'ValueError'>
# 0:00:01.165528
# 233 10
# <class 'ValueError'>
# 0:00:01.183570
# 232 10
# <class 'ValueError'>
# 0:00:01.178819
# 231 10
# <class 'ValueError'>
# 0:00:01.191131
# 230 10
# <class 'ValueError'>
# 0:00:01.180056
# 229 10
# <class 'ValueError'>
# 0:00:01.183790
# 228 10
# <class 'ValueError'>
# 0:00:01.181892
# 227 10
# <class 'ValueError'>
# 0:00:01.194753
# 226 10
# <class 'ValueError'>
# 0:00:01.206646
# 225 10
# <class 'ValueError'>
# 0:00:01.195081
# 224 10
# <class 'ValueError'>
# 0:00:01.195153
# 223 10
# <class 'ValueError'>
# 0:00:01.212360
# 222 10
# <class 'ValueError'>
# 0:00:01.210256
# 221 10
# <class 'ValueError'>
# 0:00:01.207423
# 220 10
# <class 'ValueError'>
# 0:00:01.201865
# 219 10
# <class 'ValueError'>
# 0:00:01.207315
# 218 10
# <class 'ValueError'>
# 0:00:01.212019
# 217 10
# <class 'ValueError'>
# 0:00:01.206780
# 216 10
# <class 'ValueError'>
# 0:00:01.216923
# 215 10
# <class 'ValueError'>
# 0:00:01.208742
# 214 10
# <class 'ValueError'>
# 0:00:01.229590
# 213 10
# <class 'ValueError'>
# 0:00:01.225715
# 212 10
# <class 'ValueError'>
# 0:00:01.232817
# 211 10
# <class 'ValueError'>
# 0:00:01.266053
# 210 10
# <class 'ValueError'>
# 0:00:01.232199
# 209 10
# <class 'ValueError'>
# 0:00:01.267084
# 208 10
# <class 'ValueError'>
# 0:00:01.265473
# 207 10
# <class 'ValueError'>
# 0:00:01.261994
# 206 10
# <class 'ValueError'>
# 0:00:01.291631
# 205 10
# <class 'ValueError'>
# 0:00:01.325236
# 204 10
# <class 'ValueError'>
# 0:00:01.295157
# 203 10
# <class 'ValueError'>
# 0:00:01.319760
# 202 10
# <class 'ValueError'>
# 0:00:01.285320
# 201 10
# <class 'ValueError'>
# 0:00:01.265012
# 200 10
# <class 'ValueError'>
# 0:00:01.274530
# 199 10
# <class 'ValueError'>
# 0:00:01.261311
# 198 10
# <class 'ValueError'>
# 0:00:01.278473
# 197 10
# <class 'ValueError'>
# 0:00:01.308445
# 196 10
# <class 'ValueError'>
# 0:00:01.309099
# 195 10
# <class 'ValueError'>
# 0:00:01.333732
# 194 10
# <class 'ValueError'>
# 0:00:01.309205
# 193 10
# <class 'ValueError'>
# 0:00:01.321007
# 192 10
# <class 'ValueError'>
# 0:00:01.337062
# 191 10
# <class 'ValueError'>
# 0:00:01.319112
# 190 10
# <class 'ValueError'>
# 0:00:01.396019
# 189 10
# <class 'ValueError'>
# 0:00:01.387707
# 188 10
# <class 'ValueError'>
# 0:00:01.423722
# 187 10
# <class 'ValueError'>
# 0:00:01.415956
# 186 10
# <class 'ValueError'>
# 0:00:01.429141
# 185 10
# <class 'ValueError'>
# 0:00:01.427047
# 184 10
# <class 'ValueError'>
# 0:00:01.358535
# 183 10
# <class 'ValueError'>
# 0:00:01.421943
# 182 10
# <class 'ValueError'>
# 0:00:01.379273
# 181 10
# <class 'ValueError'>
# 0:00:01.396391
# 180 10
# <class 'ValueError'>
# 0:00:01.417683
# 179 10
# <class 'ValueError'>
# 0:00:01.423030
# 178 10
# <class 'ValueError'>
# 0:00:01.441521
# 177 10
# <class 'ValueError'>
# 0:00:01.467877
# 176 10
# <class 'ValueError'>
# 0:00:01.456820
# 175 10
# <class 'ValueError'>
# 0:00:01.447932
# 174 10
# <class 'ValueError'>
# 0:00:01.438871
# 173 10
# <class 'ValueError'>
# 0:00:01.408177
# 172 10
# <class 'ValueError'>
# 0:00:01.421898
# 171 10
# <class 'ValueError'>
# 0:00:01.424465
# 170 10
# <class 'ValueError'>
# 0:00:01.413284
# 169 10
# <class 'ValueError'>
# 0:00:01.427115
# 168 10
# <class 'ValueError'>
# 0:00:01.412725
# 167 10
# <class 'ValueError'>
# 0:00:01.418209
# 166 10
# <class 'ValueError'>
# 0:00:01.424785
# 165 10
# <class 'ValueError'>
# 0:00:01.427932
# 164 10
# <class 'ValueError'>
# 0:00:01.423962
# 163 10
# <class 'ValueError'>
# 0:00:01.430815
# 162 10
# <class 'ValueError'>
# 0:00:01.444877
# 161 10
# <class 'ValueError'>
# 0:00:01.440836
# 160 10
# <class 'ValueError'>
# 0:00:01.448326
# 159 10
# <class 'ValueError'>
# 0:00:01.451800
# 158 10
# <class 'ValueError'>
# 0:00:01.497867
# 157 10
# <class 'ValueError'>
# 0:00:01.515131
# 156 10
# <class 'ValueError'>
# 0:00:01.461329
# 155 10
# <class 'ValueError'>
# 0:00:01.464731
# 154 10
# <class 'ValueError'>
# 0:00:01.468161
# 153 10
# <class 'ValueError'>
# 0:00:01.529287
# 152 10
# <class 'ValueError'>
# 0:00:01.504137
# 151 10
# <class 'ValueError'>
# 0:00:01.489920
# 150 10
# <class 'ValueError'>
# 0:00:01.506767
# 149 10
# <class 'ValueError'>
# 0:00:01.507187
# 148 10
# <class 'ValueError'>
# 0:00:01.519042
# 147 10
# <class 'ValueError'>
# 0:00:01.531347
# 146 10
# <class 'ValueError'>
# 0:00:01.529953
# 145 10
# <class 'ValueError'>
# 0:00:01.556072
# 144 10
# <class 'ValueError'>
# 0:00:01.551795
# 143 10
# <class 'ValueError'>
# 0:00:01.539589
# 142 10
# <class 'ValueError'>
# 0:00:01.557458
# 141 10
# <class 'ValueError'>
# 0:00:01.565164
# 140 10
# <class 'ValueError'>
# 0:00:01.570458
# 139 10
# <class 'ValueError'>
# 0:00:01.574945
# 138 10
# <class 'ValueError'>
# 0:00:01.631748
# 137 10
# <class 'ValueError'>
# 0:00:01.695409
# 136 10
# <class 'ValueError'>
# 0:00:01.633794
# 135 10
# <class 'ValueError'>
# 0:00:01.584494
# 134 10
# <class 'ValueError'>
# 0:00:01.594226
# 133 10
# <class 'ValueError'>
# 0:00:01.579116
# 132 10
# <class 'ValueError'>
# 0:00:01.585554
# 131 10
# <class 'ValueError'>
# 0:00:01.602149
# 130 10
# <class 'ValueError'>
# 0:00:01.627311
# 129 10
# <class 'ValueError'>
# 0:00:01.639799
# 128 10
# <class 'ValueError'>
# 0:00:01.627067
# 127 10
# <class 'ValueError'>
# 0:00:01.658882
# 126 10
# <class 'ValueError'>
# 0:00:01.666986
# 125 10
# <class 'ValueError'>
# 0:00:01.712869
# 124 10
# <class 'ValueError'>
# 0:00:01.702601
# 123 10
# <class 'ValueError'>
# 0:00:01.698369
# 122 10
# <class 'ValueError'>
# 0:00:01.745938
# 121 10
# <class 'ValueError'>
# 0:00:01.725712
# 120 10
# <class 'ValueError'>
# 0:00:01.725745
# 119 10
# <class 'ValueError'>
# 0:00:01.719878
# 118 10
# <class 'ValueError'>
# 0:00:01.763588
# 117 10
# <class 'ValueError'>
# 0:00:01.736742
# 116 10
# <class 'ValueError'>
# 0:00:01.782123
# 115 10
# <class 'ValueError'>
# 0:00:01.787090
# 114 10
# <class 'ValueError'>
# 0:00:01.764523
# 113 10
# <class 'ValueError'>
# 0:00:01.802266
# 112 10
# <class 'ValueError'>
# 0:00:01.810884
# 111 10
# ['And, the tool we are going to use for remote wipe is Computrace which our company has subscribed since 2010 back when we were still FrontRange Solutions.\nAttached is the link where you can follow now to download and install the Computrace agent for Windows (the MSI file) and the agent for Mac (TAR files in the ZIP), respectively. Once installed, the agent should call in at least once in 24 hrs, and eventually the host or device should be registered and searchable under HEAT’s account at Absolute Customer Center web site. I believe you are an expert on Computrace so I should not explain too much.\nTo help me locate the right']
# total vector size - 1
# time to replace -
# 0:00:00.024827
# 0:00:01.651883
# 110 10
# <class 'ValueError'>
# 0:00:01.917079
# 109 10
# ['network will be disabled until an IT Administrator unlocks your account.\nMobile Devices and Tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain.\n   Network passwords are valid for a period of 90 days Password cannot be any of the 5 previously used passwords Passwords must contain 3 of the 4 types of characters    Uppercase (example: A) Lowercase (example: a) Number (example: 1) Symbol (example: $, @, etc.)   \nIf you have any questions or need further assistance, please contact the IT Service Desk by logging an incident through']
# total vector size - 1
# time to replace -
# 0:00:00.030251
# 0:00:01.659344
# 108 10
# <class 'ValueError'>
# 0:00:01.963624
# 107 10
# <class 'ValueError'>
# 0:00:01.799900
# 106 10
# <class 'ValueError'>
# 0:00:01.783391
# 105 10
# <class 'ValueError'>
# 0:00:01.809975
# 104 10
# <class 'ValueError'>
# 0:00:01.808538
# 103 10
# <class 'ValueError'>
# 0:00:01.834294
# 102 10
# <class 'ValueError'>
# 0:00:01.876841
# 101 10
# <class 'ValueError'>
# 0:00:01.904479
# 100 10
# <class 'ValueError'>
# 0:00:01.854811
# 99 10
# <class 'ValueError'>
# 0:00:01.875143
# 98 10
# <class 'ValueError'>
# 0:00:01.887201
# 97 10
# <class 'ValueError'>
# 0:00:01.962870
# 96 10
# <class 'ValueError'>
# 0:00:01.905794
# 95 10
# <class 'ValueError'>
# 0:00:01.979409
# 94 10
# <class 'ValueError'>
# 0:00:01.985003
# 93 10
# ['This message is intended for the addressee(s) only and may contain confidential or privileged \ninformation. Any use of this information by persons other than addressee(s) is prohibited. If you \nhave received this message in error, please reply to the sender and delete or destroy all copies.\n This message is intended for the addressee(s) only and may contain confidential or privileged \ninformation. Any use of this information by persons other than addressee(s) is prohibited. If you \nhave received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)']
# total vector size - 1
# time to replace -
# 0:00:00.025085
# 0:00:01.829390
# 92 10
# <class 'ValueError'>
# 0:00:02.091193
# 91 10
# <class 'ValueError'>
# 0:00:01.940220
# 90 10
# <class 'ValueError'>
# 0:00:01.951310
# 89 10
# <class 'ValueError'>
# 0:00:01.952500
# 88 10
# <class 'ValueError'>
# 0:00:01.964689
# 87 10
# ['    Which systems and at what access level will they need? \nIf you are not sure about needed roles or access please note this in your incident request and we will work with you to determine what is needed.    NetSuite, if yes what roles? Global Support Services HEATCloud, if yes what roles? Release Management (RM), if yes what roles? Ektron Web Content Management System (CMS), if yes what roles? SalesForce.com and/or Marketo, if yes what roles?    Will the']
# total vector size - 1
# time to replace -
# 0:00:00.034534
# 0:00:01.849947
# 86 10
# <class 'ValueError'>
# 0:00:02.126808
# 85 10
# <class 'ValueError'>
# 0:00:01.998853
# 84 10
# <class 'ValueError'>
# 0:00:02.008344
# 83 10
# <class 'ValueError'>
# 0:00:02.014766
# 82 10
# <class 'ValueError'>
# 0:00:02.028626
# 81 10
# <class 'ValueError'>
# 0:00:02.043419
# 80 10
# [' SCCM does not address 3rd party patching natively and it takes 4-6 hours to create a patch for just one application version – why not automate that process with Ivanti Software? \nWant to manage non-windows and 3rd party patching in Microsoft System Center? \n  Patch for SCCM: Third-party patch data plug-in covering over 1000 different applications/versions. Imports all of the third-party patch data directly into the SCCM console, all with no additional agents, consoles, or training required. ']
# total vector size - 1
# time to replace -
# 0:00:00.031777
# 0:00:01.954018
# 79 10
# <class 'ValueError'>
# 0:00:02.222531
# 78 10
# <class 'ValueError'>
# 0:00:02.093642
# 77 10
# ['This message is intended only for the use of the individual(s) or entity(ies) to which it is addressed and contains information that is legally privileged and confidential. If you are not the intended recipient, or the person responsible for delivering the message to the intended recipient, you are hereby notified that any dissemination, distribution or copying of this communication is strictly prohibited. All unintended recipients are obliged to delete this message and destroy any printed copies. (AutoClosed)']
# total vector size - 1
# time to replace -
# 0:00:00.027631
# 0:00:02.015150
# 76 10
# <class 'ValueError'>
# 0:00:02.254814
# 75 10
# <class 'ValueError'>
# 0:00:02.134091
# 74 10
# <class 'ValueError'>
# 0:00:02.160397
# 73 10
# ['you can keep them for testing purpose or dispose of as you wish. The agent will also be removed at Absolute CC to free up the license.\nPS. I recall that long ago I used a Computrace tool named CTMWEB.EXE for Windows that would show the agent status and initiate Test Calls. I think I still have it somewhere; let me know if you need a copy to speed up the agent call-in process.']
# total vector size - 1
# time to replace -
# 0:00:00.029001
# 0:00:02.082956
# 72 10
# <class 'ValueError'>
# 0:00:02.312700
# 71 10
# <class 'ValueError'>
# 0:00:02.223048
# 70 10
# ['Note: The information contained in this email and document(s) attached are for the exclusive use of the addressee and may contain confidential, privileged and non-disclosable information. If the recipient of this email is not the addressee, such recipient is strictly prohibited from reading, photocopying, distributing or otherwise using this email or its contents in any way\nP Please consider the environment - do you really need to print this email? (AutoClosed)', 'message and any attachments are intended for the use of the addressee and may contain information that is privileged and confidential. If you are not the intended recipient, be aware that any disclosure, copying, distribution or use of the contents of this message is prohibited. If you have received this message in error, please notify us by reply email and delete the message and any attachments from your system. (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.039295
# 0:00:02.160027
# 69 10
# ['message and any attachments are intended for the use of the addressee and may contain information that is privileged and confidential. If you are not the intended recipient, be aware that any disclosure, copying, distribution or use of the contents of this message is prohibited. If you have received this message in error, please notify us by reply email and delete the message and any attachments from your system.', 'on the Deliver link to have that message delivered to your primary inbox.\n Click on the Whitelist link to have that message delivered to your primary inbox and that sender whitelisted.\n Click on the Delete link to remove that message from your quarantine.\n Click on the View link to display that message in a new Message Details browser window. \nView your entire Quarantine Inbox or manage your preferences. (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.040849
# 0:00:02.208407
# 68 10
# ['\n Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message.\n Please consider the environment - do you really need to print this email? (AutoClosed)']
# total vector size - 1
# time to replace -
# 0:00:00.023734
# 0:00:02.169894
# 67 10
# <class 'ValueError'>
# 0:00:02.288946
# 66 10
# <class 'ValueError'>
# 0:00:02.161028
# 65 10
# <class 'ValueError'>
# 0:00:02.205486
# 64 10
# <class 'ValueError'>
# 0:00:02.197197
# 63 10
# ['Software (Lumension is now part of the HEAT Software group) \nThis email message is for the sole use of the intended recipient(s) and may contain proprietary, confidential or attorney-client privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)']
# total vector size - 1
# time to replace -
# 0:00:00.024809
# 0:00:02.163299
# 62 10
# ['Software (Lumension is now part of the HEAT Software group)\nThis email message is for the sole use of the intended recipient(s) and may contain proprietary, confidential or attorney-client privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)']
# total vector size - 1
# time to replace -
# 0:00:00.028478
# 0:00:02.421751
# 61 10
# <class 'ValueError'>
# 0:00:02.511214
# 60 10
# ['Software (Lumension is now part of the HEAT Software group)\nThis email message is for the sole use of the intended recipient(s) and may contain proprietary, confidential or attorney-client privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original']
# total vector size - 1
# time to replace -
# 0:00:00.028759
# 0:00:02.350969
# 59 10
# <class 'ValueError'>
# 0:00:02.542275
# 58 10
# <class 'ValueError'>
# 0:00:02.469753
# 57 10
# ['Note: The information contained in this email and document(s) attached are for the exclusive use of the addressee and may contain confidential, privileged and non-disclosable information. If the recipient of this email is not the addressee, such recipient is strictly prohibited from reading, photocopying, distributing or otherwise using this email or its contents in any way (AutoClosed)', 'Software (Lumension is now part of the HEAT Software group)\n This message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.037230
# 0:00:02.410730
# 56 10
# <class 'ValueError'>
# 0:00:02.605562
# 55 10
# ['\n Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)', ' Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)', '?\n Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)', 'a look at our "Why Choose GoldMine CRM" video.\n This message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all copies.']
# total vector size - 4
# time to replace -
# 0:00:00.071859
# 0:00:02.453461
# 54 10
# <class 'ValueError'>
# 0:00:02.608628
# 53 10
# ['Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message.', 'Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. \nIf you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)', 'Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message (AutoClosed)', 'Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)', 'This email message is for the sole use of the intended recipient(s) and may contain proprietary, confidential or attorney-client privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)']
# total vector size - 5
# time to replace -
# 0:00:00.075425
# 0:00:02.477981
# 52 10
# <class 'ValueError'>
# 0:00:02.606979
# 51 10
# ['Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original', 'email message is for the sole use of the intended recipient(s) and may contain proprietary, confidential or attorney-client privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message.']
# total vector size - 2
# time to replace -
# 0:00:00.044931
# 0:00:02.433529
# 50 10
# <class 'ValueError'>
# 0:00:02.635639
# 49 10
# <class 'ValueError'>
# 0:00:02.525859
# 48 10
# ['\n This message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)', ' This message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.048788
# 0:00:02.503530
# 47 10
# ['\nThis message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)', 'This message is intended for the addressee(s) only and may contain confidential or privileged \ninformation. Any use of this information by persons other than addressee(s) is prohibited. If you \nhave received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)', 'This message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)', 'This message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)']
# total vector size - 4
# time to replace -
# 0:00:00.066470
# 0:00:02.644766
# 46 10
# ['This message is intended for the addressee(s) only and may contain confidential or privileged \ninformation. Any use of this information by persons other than addressee(s) is prohibited. If you \nhave received this message in error, please reply to the sender and delete or destroy all copies.', 'message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all copies (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.041438
# 0:00:02.559797
# 45 10
# ['This message is intended for the addressee(s) only and may contain confidential or privileged information.\nAny use of this information by persons other than addressee(s) is prohibited.\nIf you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)', 'This message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all', "We've recently updated our remote access protocol and require that all users register their access. Please click the link below to access our new Juniper VPN solution and enter your network login information. Failure to register your account in time may result in your account", 'message is intended for the addressee(s) only and may contain confidential or privileged information. \nAny use of this information by persons other than addressee(s) is prohibited. \nIf you have received this message in error, please reply to the sender and delete or destroy all copies.', 'recently updated our remote access protocol and require that all users register their access. Please click the link below to access our new Juniper VPN solution and enter your network login information. Failure to register your account in time may result in your account suspension.']
# total vector size - 5
# time to replace -
# 0:00:00.081522
# 0:00:02.629110
# 44 10
# ['message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all']
# total vector size - 1
# time to replace -
# 0:00:00.030165
# 0:00:02.561392
# 43 10
# ['to manage non-windows and 3rd party patching in Microsoft System Center?\nSee LPM for Microsoft System Center – We have you covered from client to datacenter!\nLearn about the technology that delivers a multi-layer endpoint security solution and get a detailed walk-through of core platform']
# total vector size - 1
# time to replace -
# 0:00:00.029639
# 0:00:02.587415
# 42 10
# ['message is intended for the addressee(s) only and may contain confidential or privileged information.\nAny use of this information by persons other than addressee(s) is prohibited.\nIf you have received this message in error, please reply to the sender and delete or destroy all']
# total vector size - 1
# time to replace -
# 0:00:00.030457
# 0:00:02.754417
# 41 10
# <class 'ValueError'>
# 0:00:02.770746
# 40 10
# ['need to be issued a company cell phone?   To which email distribution lists will they need to be added?   \nPlease provide this information by placing an incident request and specifying to which systems and what privileges']
# total vector size - 1
# time to replace -
# 0:00:00.029207
# 0:00:02.647898
# 39 10
# ['e-mail and any attachment is confidential and may be privileged. Any unauthorized use, disclosure, dissemination or copying of this email is strictly prohibited. If you receive it in error, please advise immediately by return e-mail and delete it. Thank']
# total vector size - 1
# time to replace -
# 0:00:00.033477
# 0:00:02.732777
# 38 10
# ['Any recordings you would like to save need to be moved over to the new heatsoftware.webex.com site. If you do not move your recordings over to the new heatsoftware.webex.com site, they will no longer be accessible after the', 'This incident has been placed in Resolved status. This incident will remain in Resolved Status for seven (7) days at which point it will automatically close. \nNext steps: Reply Close This Incident or Reply Incident Not Resolved ']
# total vector size - 2
# time to replace -
# 0:00:00.041421
# 0:00:02.764955
# 37 10
# <class 'ValueError'>
# 0:00:02.803671
# 36 10
# ['This message could not be sent. Try sending the message again later, or contact your network administrator. You do not have the permission to send the message on behalf of the specified user. Error is [0x80070005-0x0004dc-0x000524].', 'do not have the level of access necessary to perform the operation you requested. Please contact the owner of the record or your administrator if access is necessary. For more information, see Insufficient Privileges Errors. ', 'systems and at what access level will they need? \nIf you are not sure about needed roles or access please note this in your incident request and we will work with you to determine what is']
# total vector size - 3
# time to replace -
# 0:00:00.056965
# 0:00:02.770325
# 35 10
# <class 'ValueError'>
# 0:00:02.849028
# 34 10
# ['\nSet up team: Please ensure you have set up the contingent worker in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.', '2015 \nSet up team: Please ensure you have set up the employee in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.', '2016 \nSet up team: Please ensure you have set up the employee in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.', 'IT Assistance? Please log a Service Request or Incident at https://it.heatsoftware.com. If this is an urgent matter affecting multiple people or a down Production application, please call the HELP Line @ x4357 (719-268-4357). (AutoClosed)', "network. If you are remote you must connect to the Cisco AnyConnect VPN first.\nPress the Ctrl + Alt + Delete keys simultaneously from your Windows workstation and select 'Change Password' from the available options.\n"]
# total vector size - 5
# time to replace -
# 0:00:00.081761
# 0:00:02.856472
# 33 10
# [')\nSet up team: Please ensure you have set up the employee in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.']
# total vector size - 1
# time to replace -
# 0:00:00.028453
# 0:00:02.892992
# 32 10
# ['up team: Please ensure you have set up the employee in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.']
# total vector size - 1
# time to replace -
# 0:00:00.030761
# 0:00:02.939098
# 31 10
# ['site is decommissioned. For instructions on how to move your recordings, please see the attached instructions. Your recordings WILL BE LOST if you do not move them over to the new']
# total vector size - 1
# time to replace -
# 0:00:00.032231
# 0:00:02.973743
# 30 10
# <class 'ValueError'>
# 0:00:03.022651
# 29 10
# <class 'ValueError'>
# 0:00:03.028158
# 28 10
# ["The e-mail address you entered couldn't be found. Please check the recipient's e-mail address and try to resend the message. If the problem continues, please contact your helpdesk.", "The email address you entered couldn't be found. Please check the recipient's email address and try to resend the message. If the problem continues, please contact your helpdesk.", 'Verify your account: If the "Current User " is listed as Managed then proceed to step 5 as your account is a domain account. Otherwise go to step', "We can't log you in. Check for an invalid assertion in the SAML Assertion Validator (available in Single Sign-On Settings) or check the login history for failed logins.", "can't log you in. Check for an invalid assertion in the SAML Assertion Validator (available in Single Sign-On Settings) or check the login history for failed logins. (AutoClosed)", 'user name or password, please try again. Note: You may not be able to change or reset your password from Workday if your account uses a corporate password.']
# total vector size - 6
# time to replace -
# 0:00:00.092982
# 0:00:03.115793
# 27 10
# ['The server has tried to deliver this message, without success, and has stopped trying. Please try sending this message again. If the problem continues, contact your helpdesk.', 'ensure their first day is as seamless as possible please provide us with the following information no later than 10 days prior to their start date..\n ']
# total vector size - 2
# time to replace -
# 0:00:00.048059
# 0:00:03.147733
# 26 10
# ['\nSet up team: Please ensure you have set up the contingent worker in the\nFor any questions related to set up or term, the Manager should be', 'Set up team: Please ensure you have set up the contingent worker in the\nFor any questions related to set up or term, the Manager should be', 'Set up team: Please ensure you have set up the employee in the assigned\nFor any questions related to set up or term, the Manager should be', 'with the\nSet up team: Please ensure you have enabled access for the Contractor in\nFor any questions related to set up or term, the Manager should be']
# total vector size - 4
# time to replace -
# 0:00:00.067327
# 0:00:03.216700
# 25 10
# ["Term Team: Please disable and update all areas affected by the employee's termination.\nFor any questions related to setup or term, the Manager should be notified.", 'Your WebEx Productivity Tools can only be assigned to one account. To connect your productivity tools to your new heatsoftware.webex.com account, please see the attached', 'ensure their first day is as seamless as possible please provide us with the following information no later than 10 days prior to their start', 'you made this request, click the link below. If you did not make this request, do not click the link, and contact your account administrator.']
# total vector size - 4
# time to replace -
# 0:00:00.074609
# 0:00:03.301756
# 24 10
# ['up team: Please ensure you have enabled access for the Contractor in\nFor any questions related to set up or term, the Manager should be']
# total vector size - 1
# time to replace -
# 0:00:00.030975
# 0:00:03.297374
# 23 10
# ['A problem occurred during the delivery of this message. Please try to resend the message later. If the problem continues, contact your helpdesk.', 'Term Team: Please disable and update all areas affected by the\nFor any questions related to set up or term, the Manager should be', "message wasn't delivered due to a permission or security issue. It may have been rejected by a moderator, the address may only accept", 'up team: Please ensure you have terminated access for the Contractor\nFor any questions related to set up or term, the Manager should be']
# total vector size - 4
# time to replace -
# 0:00:00.069304
# 0:00:03.370001
# 22 10
# ['\nIf you run into any issues with updating your information or have any questions, please contact the IT helpdesk by emailing it.incidents@heatsoftware.com.', 'in the assigned areas for which you are responsible.\nFor any questions related to set up or term, the Manager should be notified.', 'you brought over from Absolute Software, who has been pushing us to complete the wipe since the acquisition was announced.\nTo my understanding,']
# total vector size - 3
# time to replace -
# 0:00:00.060592
# 0:00:03.419176
# 21 10
# ['                    ', 'could you please tell me the Model, Host/Device Name, and Serial Number we need to wipe? Also, please let me know']
# total vector size - 2
# time to replace -
# 0:00:00.052347
# 0:00:03.468797
# 20 10
# ['- Waiting for more information to fulfill the request\nPlease note that we need additional information to fulfill following Service Request:', 'IT Assistance? If this is an urgent matter affecting multiple work colleagues and / or a Production application down affecting', 'you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original']
# total vector size - 3
# time to replace -
# 0:00:00.056493
# 0:00:03.532799
# 19 10
# [' Lumension – a member of HEAT Software Group | 8660 East Hartford Drive, Suite 300 | Scottsdale, AZ', 'I can initiate the wiping once I can locate your systems based on the info you will provide.\nAfter the', 'emails listed below are ones that have been placed in your quarantine digest since the last quarantine summary was', 'select Change Password.\nRemember, failure to change your password before it expires will lock your account and access to the', 'the intended recipient, you are hereby notified that any dissemination, distribution or copying of this communication is strictly prohibited.']
# total vector size - 5
# time to replace -
# 0:00:00.097377
# 0:00:03.646544
# 18 10
# ['Please ensure you have all of your recordings and meetings rescheduled or moved to the new heatsoftware.webex.com site', "because you are not assigned this app in Okta.\nIf you're wondering why this is happening, please contact your"]
# total vector size - 2
# time to replace -
# 0:00:00.042644
# 0:00:03.652048
# 17 10
# ['Thanks,  Jerrica Owens-Reeder, Sales Operations Analyst Heat Software | Office: (408) 601-2918 |Cell: (469) 888-0587 (AutoClosed)', 'will need access. \nPlease do not reply to this email as it is an automated message. (AutoClosed)']
# total vector size - 2
# time to replace -
# 0:00:00.042744
# 0:00:03.703007
# 16 10
# ["  This message hasn't been delivered yet. Delivery will continue to be attempted.  ", 'This is James and I have been tasked to follow up with you for wiping the', "haven't selected an answer to your password hint. Try the following: Contact your company's administrator for"]
# total vector size - 3
# time to replace -
# 0:00:00.066428
# 0:00:03.806708
# 15 10
# ['IT Service Desk would like to notify you that your Domain password will expire at', 'to step 5 to sync your password to login to your Mac with the Network']
# total vector size - 2
# time to replace -
# 0:00:00.047299
# 0:00:03.846726
# 14 10
# ['    Delivery is delayed to these recipients or groups:  ', 'Back to the System Preferences/Users & Groups windows; On the Current User select Change', 'Please check Solarwinds to find out about the components of this application being down.', 'email message is for the sole use of the intended recipient(s) and may contain']
# total vector size - 4
# time to replace -
# 0:00:00.082209
# 0:00:03.947097
# 13 10
# ['            ', 'I am unable to login in to RM site (support.heatsoftware.com) with my credentials.', 'Please consider the environment - do you really need to print this email?', 'Please speak to your Human Resources department to get your profile data corrected.', 'The Service Desk & Support Show June 8-9, stand #706 Register FREE here', 'Windows login attempts failed for more than 3 times and domain account is', 'address. Try sending this message again. If the problem continues, please contact your', 'consider the environment - do you really need to print this email? (AutoClosed)', 'node has recovered and is back up: CSvpn200  in  CS at']
# total vector size - 9
# time to replace -
# 0:00:00.143834
# 0:00:04.067290
# 12 10
# ['\n HEAT Software (Lumension is now part of the HEAT Software group)', 'In order to change your password you must be connected to the', 'is on hold until we receive additional information, as was previously requested.']
# total vector size - 3
# time to replace -
# 0:00:00.059081
# 0:00:04.042074
# 11 10
# ['\nHEAT Software (Lumension is now part of the HEAT Software group)', '  Andrew Gauer Technical Support Analyst - UEMS HEAT Software', 'HEAT Software (Lumension is now part of the HEAT Software group)', 'HEAT Software (Lumension is now part of the Heat Software group)', 'We look forward to assisting you with any technology needs for', 'Your message did not reach some or all of the intended', 'intended only for the person or entity to which it is', "it's any consolation, we can take you to your Okta home", 'message did not reach some or all of the intended recipients.\n', 'the new hire need to be issued a company cell phone?', 'to manage non-windows and 3rd party patching in Microsoft System Center?\nSee']
# total vector size - 11
# time to replace -
# 0:00:00.179011
# 0:00:04.225577
# 10 10
# [': new support telephone number for the UK : +44', 'Software (Lumension is now part of the HEAT Software group)', 'Software( Lumension is now part of the HEAT Software group)', 'Support Renewal Team Lead – USA, Canada, and Latin America', 'Thanks,  Jerrica Owens-Reeder, Sales Operations Analyst Heat Software |', 'are currently no logon servers available to service the logon', 'privileged information. Any unauthorized review, use, disclosure or distribution is', 'received a request to reset the password for your NetSuite', 'to manage non-windows and 3rd party patching in Microsoft System', 'unexpected error has occurred. Your development organization has been notified.', 'which email distribution lists will they need to be added?']
# total vector size - 11
# time to replace -
# 0:00:00.166540
# 0:00:04.276934
# Total Time: -
# 0:08:27.348034

# %%
# temp.to_csv("junk_clean_repeated_chunks_removed_all.csv")
