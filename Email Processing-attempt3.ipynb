# %%
import numpy as np
import pandas as pd
import re
import string
import matplotlib
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier,RidgeClassifier,PassiveAggressiveClassifier
import pickle
from sklearn.metrics import precision_recall_fscore_support,accuracy_score
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
from datetime import datetime
import matplotlib.pyplot as plt
#from pandas_ml import ConfusionMatrix 
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix 
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
input_df = pd.read_csv('incident_1month_resolved.csv')
input_df = input_df[(input_df["Source"] == "Email")]
input_df = input_df.reset_index()
print(input_df.shape)
input_df['Symptom'] = input_df['Symptom'].replace(regex='(\r\n(\\s+)?)+',value='\r\n ')
# input_df = input_df.sample(1000)
# input_df = input_df.reset_index()
# print(input_df.shape)
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\n+',value='\n')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\r+',value='\r')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\+',value=' PLUS ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\|',value=' ORR ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='[\\s]+',value=' ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\-',value=' HYP ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\(',value=' OB ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\)',value=' CB ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\-',value=' HYP ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\@',value=' @ ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\.',value=' . ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex=':',value=' : ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\[',value=' [ ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\]',value=' ] ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\<',value=' < ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\>',value=' > ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\,',value=' , ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\'',value=' ' ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\=',value=' = ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\/',value=' / ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\?',value=' ? ')
# input_df['Symptom'] = input_df['Symptom'].str.lower()
# input_df.to_csv("testing.csv")
#print(input_df['Symptom'][4486])
# Out:
# (11304, 43)

# %%
import re
from datetime import datetime
import itertools

def parse_text(text):
    for pattern, replacement in new_dict_comp.items():
        text = pattern.sub(replacement, text)
    return text

i = 50;
startTime1 = datetime.now()
input_df["New_Symptom"] = input_df["Symptom"];
for i in range(150,10,-1):
    for j in range(10,9,-1):
        startTime = datetime.now()
        print(i , j)
        try:
            pattern = "[\\S]+";
            tf_vectorizer = CountVectorizer( min_df=j,
                                            ngram_range = (i,i),
                                            analyzer='word',
                                            token_pattern=pattern
                                            )
            tf_vectorizer.fit(input_df["New_Symptom"])
            a =  zip(tf_vectorizer.get_feature_names(), itertools.repeat(""))
            new_dict = {re.escape(k) : v for k, v in a}
            new_dict_comp = {re.compile(k): v for k, v in new_dict.items()}
            input_df["New_Symptom"] = input_df["New_Symptom"].apply(parse_text)     
            len(tf_vectorizer.vocabulary_)
        except ValueError:
            print(ValueError)
        except Exception as e:
            print(e)
        print(datetime.now() - startTime)
print("Total Time: - ")
print(datetime.now() - startTime1)
# Out:
# 150 10
# 0:00:04.161008
# 149 10
# 0:00:04.514321
# 148 10
# 0:00:04.515685
# 147 10
# 0:00:04.520399
# 146 10
# 0:00:04.592935
# 145 10
# 0:00:04.540497
# 144 10
# 0:00:04.568327
# 143 10
# 0:00:04.546779
# 142 10
# 0:00:04.550164
# 141 10
# 0:00:04.568757
# 140 10
# 0:00:04.614648
# 139 10
# 0:00:04.611841
# 138 10
# 0:00:04.616400
# 137 10
# 0:00:04.729501
# 136 10
# 0:00:04.747587
# 135 10
# 0:00:04.660109
# 134 10
# 0:00:04.653753
# 133 10
# 0:00:04.673130
# 132 10
# 0:00:04.643494
# 131 10
# 0:00:04.676972
# 130 10
# 0:00:04.666874
# 129 10
# 0:00:04.750368
# 128 10
# 0:00:04.823812
# 127 10
# 0:00:04.919586
# 126 10
# 0:00:04.917553
# 125 10
# 0:00:04.904514
# 124 10
# 0:00:04.913497
# 123 10
# 0:00:04.974141
# 122 10
# 0:00:04.994818
# 121 10
# 0:00:05.027260
# 120 10
# 0:00:05.044448
# 119 10
# 0:00:04.981534
# 118 10
# 0:00:05.220429
# 117 10
# 0:00:05.246482
# 116 10
# 0:00:05.326515
# 115 10
# 0:00:05.376532
# 114 10
# 0:00:05.564336
# 113 10
# 0:00:05.989946
# 112 10
# ...

# %%
from nltk import word_tokenize
raw = 'Hi Team,\n \nCan you please consider my email i sent on 15.07.2016 and take a look at this issue?\nI still have this problem , and the emails I sent are returning with this message: ‘’ System Administrator ‘’ – Undelieverable ‘’\nSee the attachments please and help in solving this issue asap\n\nThanks a lot and have a nice day!\n\nEliza\n\nElizabeta Sandor – Barbu\nFinance & Sales Admin for Central Region\n\nHEAT Software\nTelefon: +49 711 / 340190-5411\n E-Mail: elizabeta.sandor-barbu@heatsoftware.com  | www.heatsoftware.com\nHEAT Software Deutschland GmbH| Gottlieb-Manz-Straße 10| 70794 Filderstadt | Germany\n\nManagement Board: John Ferron, Anton Kreuzer, Register Court: AG - München. Commercial Register Number: HRB 13 01 11. Value added tax identification number: DE 206 863 402.\n\n '
tokens = word_tokenize(raw)
tokens
# Out:
# ['Hi',
#  'Team',
#  ',',
#  'Can',
#  'you',
#  'please',
#  'consider',
#  'my',
#  'email',
#  'i',
#  'sent',
#  'on',
#  '15.07.2016',
#  'and',
#  'take',
#  'a',
#  'look',
#  'at',
#  'this',
#  'issue',
#  '?',
#  'I',
#  'still',
#  'have',
#  'this',
#  'problem',
#  ',',
#  'and',
#  'the',
#  'emails',
#  'I',
#  'sent',
#  'are',
#  'returning',
#  'with',
#  'this',
#  'message',
#  ':',
#  '‘',
#  '’',
#  'System',
#  'Administrator',
#  '‘',
#  '’',
#  '–',
#  'Undelieverable',
#  '‘',
#  '’',
#  'See',
#  'the',
#  'attachments',
#  'please',
#  'and',
#  'help',
#  'in',
#  'solving',
#  'this',
#  'issue',
#  'asap',
#  'Thanks',
#  'a',
#  'lot',
#  'and',
#  'have',
#  'a',
#  'nice',
#  'day',
#  '!',
#  'Eliza',
#  'Elizabeta',
#  'Sandor',
#  '–',
#  'Barbu',
#  'Finance',
#  '&',
#  'Sales',
#  'Admin',
#  'for',
#  'Central',
#  'Region',
#  'HEAT',
#  'Software',
#  'Telefon',
#  ':',
#  '+49',
#  '711',
#  '/',
#  '340190-5411',
#  'E-Mail',
#  ':',
# ...

# %%
tf_vectorizer = CountVectorizer(
                                            ngram_range = (1,1),
                                            analyzer='word',
                                            tokenizer=lambda x: x.split(' ')
                                            )
tf_vectorizer.fit(["agvfh" ,"kjjkljls", 'Hi Team,\n \nCan you please consider my email i sent on 15.07.2016 and take a look at this issue?\nI still have this problem , and the emails I sent are returning with this message: ‘’ System Administrator ‘’ – Undelieverable ‘’\nSee the attachments please and help in solving this issue asap\n\nThanks a lot and have a nice day!\n\nEliza\n\nElizabeta Sandor – Barbu\nFinance & Sales Admin for Central Region\n\nHEAT Software\nTelefon: +49 711 / 340190-5411\n E-Mail: elizabeta.sandor-barbu@heatsoftware.com  | www.heatsoftware.com\nHEAT Software Deutschland GmbH| Gottlieb-Manz-Straße 10| 70794 Filderstadt | Germany\n\nManagement Board: John Ferron, Anton Kreuzer, Register Court: AG - München. Commercial Register Number: HRB 13 01 11. Value added tax identification number: DE 206 863 402.\n\n '])
tf_vectorizer.get_feature_names()
# Out:
# ['',
#  '\ncan',
#  '&',
#  '+49',
#  ',',
#  '-',
#  '/',
#  '01',
#  '10|',
#  '11.',
#  '13',
#  '15.07.2016',
#  '206',
#  '340190-5411\n',
#  '402.\n\n',
#  '70794',
#  '711',
#  '863',
#  'a',
#  'added',
#  'admin',
#  'administrator',
#  'ag',
#  'agvfh',
#  'and',
#  'anton',
#  'are',
#  'asap\n\nthanks',
#  'at',
#  'attachments',
#  'barbu\nfinance',
#  'board:',
#  'central',
#  'commercial',
#  'consider',
#  'court:',
#  'day!\n\neliza\n\nelizabeta',
#  'de',
#  'deutschland',
#  'e-mail:',
#  'elizabeta.sandor-barbu@heatsoftware.com',
#  'email',
#  'emails',
#  'ferron,',
#  'filderstadt',
#  'for',
#  'germany\n\nmanagement',
#  'gmbh|',
#  'gottlieb-manz-straße',
#  'have',
#  'help',
#  'hi',
#  'hrb',
#  'i',
#  'identification',
#  'in',
#  'issue',
#  'issue?\ni',
#  'john',
#  'kjjkljls',
#  'kreuzer,',
#  'look',
#  'lot',
#  'message:',
#  'my',
#  'münchen.',
#  'nice',
#  'number:',
#  'on',
#  'please',
#  'problem',
#  'region\n\nheat',
#  'register',
# ...

# %%
a = re.compile(re.escape("Confidentiality Note: This email message is for the sole use of the intended recipient(s) \
and may contain confidential and legally privileged information. Any unauthorized review, use, \
disclosure or distribution is prohibited. If you are not the intended recipient, please contact \
the sender by reply email and destroy all copies of the original message. (AutoClosed)"))
a
# Out:
# re.compile(r'Confidentiality\ Note\:\ This\ email\ message\ is\ for\ the\ sole\ use\ of\ the\ intended\ recipient\(s\)\ and\ may\ contain\ confidential\ and\ legally\ privileged\ information\.\ Any\ unauthorized\ review\,\ use\,\ disclosure\ or\ distribution\ is\ prohibited\.\ If\ you\ are\ not\ the\ intended\ recipient\,\ please\ contact\ the\ sender\ by\ reply\ email\ and\ destroy\ all\ copies\ of\ the\ original\ message\.\ \(AutoClosed\)',
# re.UNICODE)

# %%
b = input_df["New_Symptom"][]
a.sub("", b)
# Out:
# 'Hi Team,\n \nCan you please consider my email i sent on 15.07.2016 and take a look at this issue?\nI still have this problem , and the emails I sent are returning with this message: ‘’ System Administrator ‘’ – Undelieverable ‘’\nSee the attachments please and help in solving this issue asap\n\nThanks a lot and have a nice day!\n\nEliza\n\nElizabeta Sandor – Barbu\nFinance & Sales Admin for Central Region\n\nHEAT Software\nTelefon: +49 711 / 340190-5411\n E-Mail: elizabeta.sandor-barbu@heatsoftware.com  | www.heatsoftware.com\nHEAT Software Deutschland GmbH| Gottlieb-Manz-Straße 10| 70794 Filderstadt | Germany\n\nManagement Board: John Ferron, Anton Kreuzer, Register Court: AG - München. Commercial Register Number: HRB 13 01 11. Value added tax identification number: DE 206 863 402.\n\n '

# %%
sum(input_df["Symptom"] != input_df["New_Symptom"])
# Out:
# 2128

# %%
for i in range(input_df.shape[0]):
    if input_df["Symptom"][i] != input_df["New_Symptom"][i]:
        print(input_df["Symptom"][i])
        print("\n######\n")
        print(input_df["New_Symptom"][i])
        print("\n--------\n")
    if i == 30:
        break
# Out:
# Whenever I send an email to Brendan.kelley@heatsoftware.com from Outlook, I get the following error. I am able to send him emails from my phone without any issues. I deleted his saved email address from Outlook but I still have issues. I need to get this fixed asap please.   Thanks, Brian     Brian Shepard Information Technology – Enterprise Apps HEAT Software 425.210.2637 direct Brian.Shepard@heatsoftware.com | www.HEATsoftware.com        _____________________________________________
#  From: Microsoft Outlook
#  Sent: Sunday, June 26, 2016 3:31 PM
#  To: Brian Shepard
#  Subject: Undeliverable: FW: test     Delivery has failed to these recipients or groups:   Brendan Kelley
#  The email address you entered couldn't be found. Please check the recipient's email address and try to resend the message. If the problem continues, please contact your helpdesk.
#  Diagnostic information for administrators:   Generating server: cs-mbx01v.corp.lcl
# ...

# %%
input_df['Symptom'] = input_df['Symptom'].replace(regex=' plus ',value='+')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' orr ',value='|')
input_df['Symptom'] = input_df['Symptom'].replace(regex='[\\s]+',value=' ')
input_df['Symptom'] = input_df['Symptom'].replace(regex='\\-',value='HYP')
input_df['Symptom'] = input_df['Symptom'].replace(regex='ob',value='(')
input_df['Symptom'] = input_df['Symptom'].replace(regex='cb',value=')')
input_df['Symptom'] = input_df['Symptom'].replace(regex='hyp',value='-')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\@ ',value='@')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\. ',value='.')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' : ',value=':')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\[ ',value='[')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\] ',value=']')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\< ',value='<')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\> ',value='>')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\, ',value=',')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\' ',value=''')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\= ',value='=')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\/ ',value='/')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\? ',value='?')

input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='plus ',value='+')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' orr ',value='|')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='[\\s]+',value=' ')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='\\-',value='HYP')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='ob',value='(')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='cb',value=')')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex='hyp',value='-')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\@ ',value='@')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\. ',value='.')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' : ',value=':')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\[ ',value='[')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\] ',value=']')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\< ',value='<')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\> ',value='>')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\, ',value=',')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\' ',value=''')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\= ',value='=')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\/ ',value='/')
input_df['New_Symptom'] = input_df['New_Symptom'].replace(regex=' \\? ',value='?')

# %%
input_df.to_csv("attempt4.csv")

# %%
#pattern = "(?u)[\\w.@:-aeiouAEIOU&\\r\\n\\,\\-()\\']+";
try:
    pattern = "[\\S]+";
    tf_vectorizer = CountVectorizer( min_df=10,
                                    ngram_range = (10,10),
                                    analyzer='word',
                                    token_pattern=pattern
                                    )
    tf_vectorizer.fit(input_df["Symptom"])
    #tf_vectorizer.vocabulary_ 
    print(tf_vectorizer.vocabulary_)
except ValueError:
    print(ValueError)
except Exception as e:
    print(e)
# Out:
# {'150, colorado springs, co 80920 katie.sullivan@goldmine.com www.goldmine.com this message is': 327, 'multiple people or a down production application, please call the': 3084, 'business controller p: +49 (0)711 340190 5401 | m: +49': 1197, '+44(0)1635 516 701 lee.calcutt@heatsoftware.com | www.heatsoftware.com registered in england &': 206, 'purpose or dispose of as you wish. the agent will': 3740, 'ensure their first day is as seamless as possible please': 1787, 'www.heatsoftware.com this email message is for the sole use of': 5185, 'ensure you have set up the employee in the assigned': 1791, '85716 unterschleißheim germany management board: anton kreuzer, john ferron register': 592, 'lumension | 8660 e. hartford dr. suite 300 | scottsdale,': 2787, 'the deliver link to have that message delivered to your': 4667, 'regards. michael ooi, senior sales engineer heat software o :': 3853, 'of this message is prohibited. if you have received this': 3340, 'https://it.heatsoftware.com. if th
# ...

# %%
from datetime import datetime
startTime = datetime.now()
input_df["Symptom"] = input_df["Symptom"].str.lower()
a =  zip(tf_vectorizer.get_feature_names(), itertools.repeat(""))
new_dict = {re.escape(k) : v for k, v in a}
input_df["Symptom"].replace(new_dict,regex = True, inplace = True);
print(datetime.now() - startTime)
# Out:
# 0:01:17.323350

# %%
from datetime import datetime
startTime = datetime.now()
#input_df["Symptom"] = input_df["Symptom"].str.lower()
a =  zip(tf_vectorizer.get_feature_names(), itertools.repeat(""))
new_dict = {re.escape(k) : v for k, v in a}
new_dict_comp = {re.compile(k): v for k, v in new_dict.items()}
def parse_text(text):
    for pattern, replacement in new_dict_comp.items():
        text = pattern.sub(replacement, text)
    return text
input_df["Symptom"] = input_df["Symptom"].apply(parse_text)
print(datetime.now() - startTime)
# Out:
# 0:01:01.590503

# %%
header = ["Symptom","New_Symptom"]
a = input_df[ input_df['Symptom'] != input_df["New_Symptom"] ]
#print(a.iloc[3]["New_Symptom"])
#print(a.iloc[3]["Symptom"])
a.to_csv("success.csv", columns = header)
print(a.shape)
a = input_df[ input_df['Symptom'] == input_df["New_Symptom"] ]
#print(a.iloc[3]["New_Symptom"])
#print(a.iloc[3]["Symptom"])
a.to_csv("failure.csv", columns = header)
print(a.shape)

# %%
input_df = pd.read_csv('failure.csv')
input_df['Symptom'] = input_df['Symptom'].replace(regex='plus ',value='+')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' orr ',value='|')
input_df['Symptom'] = input_df['Symptom'].replace(regex='[\\s]+',value=' ')
input_df['Symptom'] = input_df['Symptom'].replace(regex='\\-',value='HYP')
input_df['Symptom'] = input_df['Symptom'].replace(regex='ob',value='(')
input_df['Symptom'] = input_df['Symptom'].replace(regex='cb',value=')')
input_df['Symptom'] = input_df['Symptom'].replace(regex='hyp',value='-')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\@ ',value='@')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\. ',value='.')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' : ',value=':')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\[ ',value='[')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\] ',value=']')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\< ',value='<')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\> ',value='>')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\, ',value=',')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\' ',value=''')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\= ',value='=')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\/ ',value='/')
input_df['Symptom'] = input_df['Symptom'].replace(regex=' \\? ',value='?')
#a = input_df[ input_df['Symptom'] == input_df["New_Symptom"] ]
input_df.to_csv("failure1.csv")
# Out:
# (1,)

# %%
input_df = pd.read_csv('success.csv')
input_df = input_df[input_df['Symptom'].str.lower().str.contains("emma wilson maintenance & renewals team lead")]["Symptom"]
print(input_df.shape)
# Out:
# (9,)

# %%
for i in range(1,13,1):
    print(a.iloc[i])
    print("------------------&&&&&&&&&&&&&&&&&&&&&--------------------")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5134b20b3eaf> in <module>()
#       1 for i in range(1,13,1):
# ----> 2     print(a.iloc[i])
#       3     print("------------------&&&&&&&&&&&&&&&&&&&&&--------------------")
#
# AttributeError: 'zip' object has no attribute 'iloc'

# %%
a = input_df['Symptom'].str.lower().str.contains("carole.strauss@heatsoftware.com")
sum(a)
# Out:
# 11

# %%
input_df['Symptom'][4099]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-ba4668c45dae> in <module>()
# ----> 1 input_df['Symptom'][4099]
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
# ...

# %%
input_df['Symptom'][4099]
a = "dach & emerging markets maintenance renewals heat software deutschland gmbh gottlieb-manz-strasse 10, 70794 filderstadt, germany p: plus 49 ob0cb711 340190-5406 orr f: plus 49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and"
import re
 
src_str  = re.compile(a, re.IGNORECASE)
 
str_replaced  = src_str.sub(" ", input_df['Symptom'][4099])
 
 
 
print(str_replaced)

# %%
for i in range(1,20):
    print(repr(input_df['Symptom'][i]))
    print("\n-------------\n")

# %%
input_df['Symptom'] = input_df['Symptom'].replace(regex='(\r\n(\\s+)?)+',value='\r\n ')

# %%
input_df['Symptom'][1163]

# %%
input_df['Symptom'] = input_df['Symptom'].replace(regex='(\r\n(\\s+)?)+',value='\r\n ')
input_df['Symptom'] = input_df['Symptom'].replace(regex=["\\sFrom:.*\\s",
                        "\\sTo:.*\\s","\\sDate:.*\\s","\\sSubject:.*\\s","\\sSent:.*\\s",
                        "\\sCc:.*\\s","\\sBcc:\\s"], value='')
input_df['Symptom'] = input_df['Symptom'].replace(regex=[                                                         
                        "(?s)\\sThis message is intended .* destroy all copies\\.?\\s",
                        "(?s)\\sDisclaimer .* only if necessary\\.?\\s",
                        "(?s)\\sConfidentiality Note:.*original message\\.?\\s"], value='')
input_df['Symptom'] = input_df['Symptom'].replace(regex='\\s?\\(AutoClosed\\)', value = '')

# %%
count = 0
index = []
for i in range(input_df.shape[0]):
    if len(input_df['Symptom'][i]) > 3000:
        count+=1
        index.append(i)
#         print(input_df['Symptom'][i])
#         print("\n-------------\n")

print(count)
print(index)

# %%
print(input_df['Symptom'][5249])

# %%
# for i in range(20):
#     print(re.findall("\\sDiagnostic information for administrators\\s", input_df['Symptom'][i]))
# #     print("\n" + input_df['Subject'][i])
#     print("\n-------------\n")

count = 0
index =[]
for j in range(input_df.shape[0]):
    if len(re.findall("o:", input_df['Symptom'][j])) > 0:
        index.append(j)
        count+=1
        
print(count)
print(index)

# %%
message = """Good morning,
 
 
 
Can you please contact me as soon as possible regarding this issue?
 
Attached is the screen Michal gets when he boots his PC
 
He is just back from holiday and nothing was done to the machine as far as we can tell
 
 
 
Thank you for your help,
 
Benjamin Elzingre
Technical Support Manager – EMEA
Ivanti
benjamin.elzingre@ivanti.com | www.heatsoftware.com | www.ivanti.com (AutoClosed)
 """

# %%
import email
b = email.message_from_string(message)
print(b)

# %%
import talon
from talon import quotations
talon.init()
from talon import signature
from talon.signature.bruteforce import extract_signature

kunal =  input_df['Symptom'].apply(lambda x : extract_signature(x) )

# %% [markdown]
# # kunal[2][1]

# %%
a = 0;
for i in kunal :
    if i[1] == None :
        a += 1;
print(a)

# %%
text

# %%
signature

# %%
signature_b

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
tagged = ne_chunk(pos_tag(word_tokenize(text)))
person = []
for subtree in tagged.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
            
print(person)

# %%
from dill.source import getsource
print(getsource(signature))
