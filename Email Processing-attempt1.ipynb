# %%
import numpy as np
import pandas as pd
import re
import string
import matplotlib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier,RidgeClassifier,PassiveAggressiveClassifier
import pickle
from sklearn.metrics import precision_recall_fscore_support,accuracy_score
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
from datetime import datetime
import matplotlib.pyplot as plt
#from pandas_ml import ConfusionMatrix 
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix 
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
input_df = pd.read_csv('incident_1month_resolved.csv')
input_df = input_df[(input_df["Source"] == "Email")][["Subject","Symptom"]]
#input_df = input_df[(input_df['Symptom'].str.contains("Brian Shepard"))]
input_df = input_df.reset_index()
print(input_df.shape)

# input_df['Symptom'] = input_df['Symptom'].replace(regex = '([[()\]|\^&+\-%*/=!>.])', value=r'\\\1')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\n+',value='\n')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\r+',value='\r')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\+',value='PLUS ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\\|',value=' ORR ')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='[\\s]+',value=' ')

# input_df['Symptom'] = input_df['Symptom'].replace(regex='\(',value='OB')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='\)',value='CB')
# input_df['Symptom'] = input_df['Symptom'].replace(regex='–',value='HYPHEN')

#print(input_df['Symptom'][4486])
# Out:
# (11304, 3)

# %%
print(input_df['Symptom'][1])
# Out:
# Al or Brian,
#
#
#
# In Netsuite, I have set up a vendor that I can see but no one else can. Could you see if I did it correctly and help me figure out how to set up a vendor that my co-workers can actually see? J
#
#
#
# Thanks,
#
#
#
# Terri
#
#
#
# ALSO:
#
# Derek,
#
#
#
# I am new to setting up vendors and am doing something wrong. I am checking with Al Sugarman or Brian Shepard for assistance. I’m sorry this is taking so long. If you want to send me the info, I can set up the PO in the meantime.
#
#
#
# Terri
#
#
#
# From: Patty Morin [mailto:Patty.Morin@heatsoftware.com]
# Sent: Monday, April 18, 2016 10:54 AM
#  To: Terri Sanchez
#  Subject: RE: Vendor set up Status
#  Importance: High
#
#
#
# Terri,
#
#
#
# It does not come up.
#
#
#
# Patty
#
#
#
# From: Terri Sanchez [mailto:Terri.Sanchez@heatsoftware.com]
# Sent: Friday, April 15, 2016 12:58 PM
#  To: Patty Morin
#  Subject: FW: Vendor set up
#
#
#
#
#
#
#
# From: Terri Sanchez
# Sent: Friday, April 15, 2016 11:59 AM
#  To: 'Derek Leung'; Art Maglabe
#  Subject: RE: Vendor set up
#
#
#
# Hi Derek,
#
#
#
# Try the below in the search line in NetSuite and let me know if it doesn’t show up.
#
#
#
#
#
#
#
# Terri
#
#
#
# From: Derek Leung [mailto:Derek.Leung@heatsoftware.com]
# Sent: Friday, April 15, 2016 11:28 AM
#  To: Terri Sanchez; Art Maglabe
#  Subject: RE: Vendor set up
#
#
#
# Hi Terri,
#
#
#
# I can’t locate Bonzzu at the vendor list?
#
#
#
# Derek
#
#
#
# From: Terri Sanchez [mailto:Terri.Sanchez@heatsoftware.com]
# Sent: Wednesday, April 13, 2016 4:10 PM
#  To: Art Maglabe
#  Cc: Derek Leung
#  Subject: RE: Vendor set up
#
#
#
# Art,
#
#
#
# Bonzzu is now set up in NetSuite.
#
#
#
# Terri McGinnis Sanchez
#
#
#
# From: Art Maglabe [mailto:Art.Maglabe@heatsoftware.com]
# Sent: Tuesday, April 12, 2016 2:19 PM
#  To: Terri Sanchez
#  Cc: Derek Leung
#  Subject: Vendor set up
#
#
#
# HI Terri,
#
#
#
# Just wanted to follow up on the vendor forms I sent yesterday. Is there anything I need to do on my end?
#
# We have projects lined up for them and need to start ASAP.
#
#
#
#
#
# Thanks,
#
#
#
# Art
#
#
#
#
#
#
#
# Art Maglabe
#
# Web Development Manager
#
# HEAT Software
#
# O:+1 408-601-2899 M:+1 408-480-1026
#
# art.maglabe@heatsoftware.com | www.HeatSoftware.com (AutoClosed)

# %%
count = 0
index =[]
for j in range(input_df.shape[0]):
    if len(re.findall("Brian Shepard",
                      input_df['Symptom'][j])) > 0:
        index.append(j)
        count+=1
        #print(input_df['Symptom'][j])
        #print("\n-------\n")
        
print(count)
#print(index)
# Out:
# 44

# %%
pattern = "[\\S]+";
tf_vectorizer = CountVectorizer( min_df=15,
                                            ngram_range = (10,10),
                                            analyzer='word',
                                            token_pattern=pattern
                                            )
tf_vectorizer.fit(input_df["Symptom"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=15,
#         ngram_range=(10, 10), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='[\\S]+', tokenizer=None,
#         vocabulary=None)

# %%
for vec in tf_vectorizer.get_feature_names():
    input_df["New_Symptom"] = input_df["Symptom"].str.lower().str.replace(vec,"");

# %%
# print(tf_vectorizer.vocabulary_)
# Out:
# {'is: anne.mcfarlane@ivanti.com we have a new address: heat software uk': 1372, 'manager heat software obformerly frontrangecb p: 719.532.7357 pam.fitz@frontrange.com orr www.heatsoftware.com': 1547, 'reply email and destroy all copies of the original message': 2277, 'analyst heat software obformerly frontrangecb 8415 explorer drive, suite 150': 425, 'heat software obformerly frontrangecb phone: plus 1 719.532.7318 orr fax:': 1198, 'now part of the heat software groupcb 480-663-8745 orr david.draper@heatsoftware.com': 1721, 'software obformerly frontrangecb p: 719-532-7336 orr f: 719-799-1074 carole.strauss@heatsoftware.com orr': 2456, 'huynh senior executive administrator heat software obformerly frontrangecb o: plus': 1268, 'plus 49 ob0cb711 340190 5401 orr m: plus 49 ob0cb173': 2142, 'original message. please consider the environment - do you really': 1876, 'heat software orr 120 robinson road, level 9 orr singapore': 1201, '10 70794 filderstadt germany management board: john ferron, m. arantzazu': 85, 'which email distribution lists will they need to be added?': 2905, 'www.heatsoftware.com 8660 e. hartford dr. suite 300 orr scottsdale, az': 2939, '70794 filderstadt germany management board: anton kreuzer, john ferron register': 248, 'have terminated access for the contractor in the assigned areas': 1144, 'intended recipient, or the person responsible for delivering the message': 1333, '<span style="color:gray"> cs-mbx01v.corp.lcl ob[fe80::6815:5357:9142:58c3%16]cb with mapi id<o:p></o:p></span> <span style="color:gray"> 15.00.1263.000;': 334, 'intended recipientobscb and may contain proprietary, confidential or attorney-client privileged': 1337, '01 11. value added tax identification number: de 206 863': 45, 'administrator heat software oblumension is now part of the heat': 395, 'for the exclusive use of the addressee and may contain': 1013, 'information. if the recipient of this email is not the': 1325, '3rd floor, capitol building, oldbury, bracknell, berkshire rg12 8fz frontrange': 158, 'f: plus 44ob0cb1635 516 701 lee.calcutt@heatsoftware.com orr www.heatsoftware.com registered in': 962, 'steffi zier channel operations manager heat software deutschland gmbh gottlieb-manz-straße': 2526, '"nfs_qa", including the related cifs shares in. netapp filer of': 6, 'request and we will work with you to determine what': 2287, 'regards, steffi zier channel operations manager heat software deutschland gmbh': 2243, 'or distribution is prohibited. if you are not the intended': 1859, 'please try to resend the message later. if the problem': 2069, 'the addressee and may contain confidential, privileged and non-disclosable information.': 2676, '340190 3415 c: plus 49 173 3147059 ralf.kaiser@heatsoftware.com www.heatsoftware.com heat': 134, 'building, oldbury, bracknell, berkshire rg12 8fz frontrange is now heat': 602, 'fs_dev1qa_cifs devicepath for storage snapshot is: 10.52.172.20:/vol/fs_dev1qa_esxnfs/fs_dev1qa_esxnfs all virtual machines': 1052, 'software uk limited capitol building, oldbury, bracknell rg12 8fz united': 2488, '1.408.601.2833 orr m: plus 1.408.674.0607 vera.gardner@heatsoftware.com orr www.heatsoftware.com this message': 79, 'software developer heat software oblumension is now part of the': 2423, '719.532.7411 orr m: plus 1 719.439.0505 stacey.slowiak@heatsoftware.com orr www.heatsoftware.com obautoclosedcb': 267, 'gmbh carl-von-linde str. 38 85716 unterschleißheim germany management board: john': 1092, 'analyst heat software orr office: ob408cb 601-2918 orr cell: ob469cb': 428, 'anne mcfarlane global customer success manager o plus 44 1344': 461, 'empower your mobile workforce with anytime, anywhere access change is': 898, '49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron,': 217, 'engineer new york, ny m plus 1-602-697-3742 w www.ivanti.com note:': 908, 'up or term, the manager should be notified. this request': 2835, 'it assistance? please log a service ...

# %%
# input_df = input_df.loc[1:30]

# %%
import re
i = 50;
input_df["New_Symptom"] = input_df["Symptom"];
for i in range(200,10,-1):
    for j in range(10,9,-1):
        print(i , j)
        try:
            pattern = "[\\S]+";
            tf_vectorizer = CountVectorizer( min_df=j,
                                            ngram_range = (i,i),
                                            analyzer='word',
                                            token_pattern=pattern
                                            )
            tf_vectorizer.fit(input_df["New_Symptom"])
            for vec in tf_vectorizer.get_feature_names():
                input_df["New_Symptom"] = input_df["New_Symptom"].str.lower().str.replace(vec,"");     
            len(tf_vectorizer.vocabulary_)
        except ValueError:
            print(ValueError)
        except Exception as e:
            print(e)
# Out:
# 200 10
# <class 'ValueError'>
# 199 10
# <class 'ValueError'>
# 198 10
# <class 'ValueError'>
# 197 10
# <class 'ValueError'>
# 196 10
# <class 'ValueError'>
# 195 10
# <class 'ValueError'>
# 194 10
# <class 'ValueError'>
# 193 10
# <class 'ValueError'>
# 192 10
# <class 'ValueError'>
# 191 10
# <class 'ValueError'>
# 190 10
# <class 'ValueError'>
# 189 10
# <class 'ValueError'>
# 188 10
# <class 'ValueError'>
# 187 10
# <class 'ValueError'>
# 186 10
# <class 'ValueError'>
# 185 10
# <class 'ValueError'>
# 184 10
# <class 'ValueError'>
# 183 10
# <class 'ValueError'>
# 182 10
# <class 'ValueError'>
# 181 10
# <class 'ValueError'>
# 180 10
# <class 'ValueError'>
# 179 10
# <class 'ValueError'>
# 178 10
# <class 'ValueError'>
# 177 10
# <class 'ValueError'>
# 176 10
# <class 'ValueError'>
# 175 10
# <class 'ValueError'>
# 174 10
# <class 'ValueError'>
# 173 10
# <class 'ValueError'>
# 172 10
# <class 'ValueError'>
# 171 10
# <class 'ValueError'>
# 170 10
# <class 'ValueError'>
# 169 10
# <class 'ValueError'>
# 168 10
# <class 'ValueError'>
# 167 10
# <class 'ValueError'>
# 166 10
# <class 'ValueError'>
# 165 10
# <class 'ValueError'>
# 164 10
# <class 'ValueError'>
# 163 10
# <class 'ValueError'>
# 162 10
# <class 'ValueError'>
# 161 10
# <class 'ValueError'>
# 160 10
# <class 'ValueError'>
# 159 10
# <class 'ValueError'>
# 158 10
# <class 'ValueError'>
# 157 10
# <class 'ValueError'>
# 156 10
# <class 'ValueError'>
# 155 10
# <class 'ValueError'>
# 154 10
# <class 'ValueError'>
# 153 10
# <class 'ValueError'>
# 152 10
# <class 'ValueError'>
# 151 10
# 150 10
# 149 10
# 148 10
# 147 10
# 146 10
# 145 10
# 144 10
# 143 10
# 142 10
# 141 10
# 140 10
# 139 10
# 138 10
# 137 10
# 136 10
# 135 10
# 134 10
# 133 10
# 132 10
# 131 10
# 130 10
# 129 10
# 128 10
# 127 10
# 126 10
# 125 10
# 124 10
# 123 10
# 122 10
# 121 10
# 120 10
# 119 10
# 118 10
# 117 10
# 116 10
# 115 10
# 114 10
# 113 10
# 112 10
# 111 10
# 110 10
# 109 10
# 108 10
# 107 10
# 106 10
# 105 10
# 104 10
# 103 10
# 102 10
# 101 10
# 100 10
# 99 10
# 98 10
# 97 10
# 96 10
# 95 10
# 94 10
# 93 10
# 92 10
# 91 10
# 90 10
# 89 10
# 88 10
# 87 10
# 86 10
# 85 10
# 84 10
# 83 10
# 82 10
# 81 10
# 80 10
# 79 10
# 78 10
# 77 10
# 76 10
# 75 10
# 74 10
# 73 10
# 72 10
# 71 10
# 70 10
# 69 10
# 68 10
# 67 10
# 66 10
# 65 10
# 64 10
# 63 10
# 62 10
# 61 10
# 60 10
# 59 10
# 58 10
# 57 10
# 56 10
# 55 10
# 54 10
# 53 10
# 52 10

# %%
for i in range(0,10):
    print(repr(input_df['Symptom'][i]))
    print("\n#########\n")
    print(repr(input_df['New_Symptom'][i]))
    print("\n-------------\n")
# Out:
# 'Best Regards,\r\n \r\n Ralph Schoell\r\n Manager, Infrastructure Systems\r\n \r\nVMware Certified Professional on vSphere 4/5\r\n \r\nNetApp Certified Data Management Administrator\r\n \r\nDSM 7 Certified Engineer\r\n \r\n \r\n \r\nNeed IT Assistance? Please call the HELP Line @ (+1.719.268.)4357 or Submit an Incident (AutoClosed)'
#
# #########
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New_Symptom'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-0f2f0097e73a> in <module>()
#       2     print(repr(input_df['Symptom'][i]))
#       3     print("\n#########\n")
# ----> 4     print(repr(input_df['New_Symptom'][i]))
#       5     print("\n-------------\n")
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New_Symptom'

# %%
#pattern = "(?u)[\\w.@:-aeiouAEIOU&\\r\\n\\,\\-()\\']+";
try:
    pattern = "[\\S]+";
    tf_vectorizer = CountVectorizer( min_df=10,
                                    ngram_range = (98,98),
                                    analyzer='word',
                                    token_pattern=pattern
                                    )
    tf_vectorizer.fit(input_df["New_Symptom"])
    #tf_vectorizer.vocabulary_ 
    print(tf_vectorizer.vocabulary_)
except ValueError:
    print(ValueError)
except:
    print("lol")
# Out:
# {'until an it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it service desk by logging': 6, 'be disabled until an it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it service desk': 2, 'network will be disabled until an it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it': 5, 'disabled until an it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it service desk by': 3, 'an it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it service desk by logging an': 1, 'it administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of characters uppercase obexample: acb lowercase obexample: acb number obexample: 1cb symbol obexample: $, @, etc.cb if you have any questions or need further assistance, please contact the it service desk by logging an incident': 4, 'administrator unlocks your account. mobile devices and tablets, please note that you may also need to change your password on your mobile device once you have changed your password on the domain. password restrictions: network passwords are valid for a period of 90 days password cannot be any of the 5 previously used passwords passwords must contain 3 of the 4 types of ...

# %%
input_df.to_csv("kunal1.csv")

# %%
print(tf_vectorizer.get_feature_names())
# Out:
# ['& emerging markets maintenance renewals heat software deutschland gmbh gottlieb-manz-strasse 10, 70794 filderstadt, germany p: plus 49 ob0cb711 340190-5406 orr f: plus 49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and destroy', '& support renewal team lead dach & emerging markets maintenance renewals heat software deutschland gmbh gottlieb-manz-strasse 10, 70794 filderstadt, germany p: plus 49 ob0cb711 340190-5406 orr f: plus 49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the', 'andreas cika heat software telefon: plus 49 711 / 340190-5411 e-mail: andreas.cika@heatsoftware.com orr www.heatsoftware.com heat software deutschland gmbh orr gottlieb-manz-straße 10 orr 70794 filderstadt orr germany management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and destroy all copies', 'andreas cika heat software telefon: plus 49 711 / 340190-5411 e-mail: andreas.cika@heatsoftware.com orr www.heatsoftware.com heat software deutschland gmbh orr gottlieb-manz-straße 10 orr 70794 filderstadt orr germany management board: john ferron, anton kreuzer, register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original', 'cika heat software telefon: plus 49 711 / 340190-5411 e-mail: andreas.cika@heatsoftware.com orr www.heatsoftware.com heat software deutschland gmbh orr gottlieb-manz-straße 10 orr 70794 filderstadt orr germany management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and destroy all copies of', 'cika heat software telefon: plus 49 711 / 340190-5411 e-mail: andreas.cika@heatsoftware.com orr www.heatsoftware.com heat software deutschland gmbh orr gottlieb-manz-straße 10 orr 70794 filderstadt orr germany management board: john ferron, anton kreuz ...

# %%
a = input_df['Symptom'].str.lower().str.contains("dach & emerging markets maintenance renewals heat software deutschland gmbh gottlieb-manz-strasse 10, 70794 filderstadt, germany p: plus 49 ob0cb711 340190-5406 orr f: plus 49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and")
a[ a == True ]
# Out:
# 203      True
# 725      True
# 812      True
# 966      True
# 1210     True
# 1233     True
# 1294     True
# 1658     True
# 1685     True
# 2008     True
# 2347     True
# 2388     True
# 2909     True
# 2963     True
# 2992     True
# 3599     True
# 4099     True
# 4486     True
# 6524     True
# 7494     True
# 7528     True
# 8671     True
# 9533     True
# 9735     True
# 9945     True
# 10608    True
# 10895    True
# 11099    True
# Name: Symptom, dtype: bool

# %%
input_df['Symptom'][4099]
# Out:
# 'Hi Bill. Can reset the password on this users account. I get the following error: Windows cannot access object Norin Zriyana because: The server is not operational. The object may have been deleted by another administrator in this enterprise. Seen this error with a few users outside the EMEA domain. I think Brad has the same issue too. na.frs/GalSynch/NA.FRS_Users/External/Service Source/Norin Zriyana ------------------------------------------------------------------------------------------------------- Dear Team, Norin Zriyana is not able to log ibn to inbox OBemailsCB. Could you please check? Thank you! Valentina Schmidt Maintenance & Support Renewal Team Lead DACH & Emerging Markets Maintenance Renewals HEAT Software Deutschland GmbH Gottlieb-Manz-Strasse 10, 70794 Filderstadt, Germany P: PLUS 49 OB0CB711 340190-5406 ORR F: PLUS 49 OB0CB711 340190-5899 valentina.schmidt@heatsoftware.com ORR www.heatsoftware.com Management Board: John Ferron, Anton Kreuzer, Jon A. Temple. Register Court: AG - München. Commercial Register Number: HRB 13 01 11. Value added tax identification number: DE 206 863 402. Confidentiality Note: This email message is for the sole use of the intended recipientOBsCB and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. OBAutoClosedCB'

# %%
input_df['Symptom'][4099]
a = "dach & emerging markets maintenance renewals heat software deutschland gmbh gottlieb-manz-strasse 10, 70794 filderstadt, germany p: plus 49 ob0cb711 340190-5406 orr f: plus 49 ob0cb711 340190-5899 valentina.schmidt@heatsoftware.com orr www.heatsoftware.com management board: john ferron, anton kreuzer, jon a. temple. register court: ag - münchen. commercial register number: hrb 13 01 11. value added tax identification number: de 206 863 402. confidentiality note: this email message is for the sole use of the intended recipientobscb and may contain confidential and legally privileged information. any unauthorized review, use, disclosure or distribution is prohibited. if you are not the intended recipient, please contact the sender by reply email and"
import re
 
src_str  = re.compile(a, re.IGNORECASE)
 
str_replaced  = src_str.sub(" ", input_df['Symptom'][4099])
 
 
 
print(str_replaced)
# Out:
# Hi Bill. Can reset the password on this users account. I get the following error: Windows cannot access object Norin Zriyana because: The server is not operational. The object may have been deleted by another administrator in this enterprise. Seen this error with a few users outside the EMEA domain. I think Brad has the same issue too. na.frs/GalSynch/NA.FRS_Users/External/Service Source/Norin Zriyana ------------------------------------------------------------------------------------------------------- Dear Team, Norin Zriyana is not able to log ibn to inbox OBemailsCB. Could you please check? Thank you! Valentina Schmidt Maintenance & Support Renewal Team Lead   destroy all copies of the original message. OBAutoClosedCB

# %%
for i in range(1,20):
    print(repr(input_df['Symptom'][i]))
    print("\n-------------\n")
# Out:
# 'Whenever I send an email to Brendan.kelley@heatsoftware.com from Outlook, I get the following error. I am able to send him emails from my phone without any issues. I deleted his saved email address from Outlook but I still have issues. I need to get this fixed asap please.   Thanks, Brian     Brian Shepard Information Technology – Enterprise Apps HEAT Software 425.210.2637 direct Brian.Shepard@heatsoftware.com | www.HEATsoftware.com        _____________________________________________\r\n From: Microsoft Outlook \r\n Sent: Sunday, June 26, 2016 3:31 PM\r\n To: Brian Shepard\r\n Subject: Undeliverable: FW: test     Delivery has failed to these recipients or groups:   Brendan Kelley\r\n The email address you entered couldn\'t be found. Please check the recipient\'s email address and try to resend the message. If the problem continues, please contact your helpdesk.\r\n Diagnostic information for administrators:   Generating server: cs-mbx01v.corp.lcl\r\n IMCEAEX-_O=GOLDMINE_OU=EXCHANGE+20ADMINISTRATIVE+20GROUP+20+28FYDIBOHF23SPDLT+29_CN=RECIPIENTS_CN=Brendan+20Kelley3ca@heatsoftware.com\r\n Remote Server returned \'550 5.1.1 RESOLVER.ADR.ExRecipNotFound; not found\'\r\n Original message headers:   Received: from cs-mbx01v.corp.lcl (10.101.25.72) by cs-mbx01v.corp.lcl\r\n (10.101.25.72) with Microsoft SMTP Server (TLS) id 15.0.1178.4; Sun, 26 Jun\r\n 2016 16:30:51 -0600\r\n Received: from cs-mbx01v.corp.lcl ([fe80::dc44:411f:46ef:62e9]) by\r\n cs-mbx01v.corp.lcl ([fe80::dc44:411f:46ef:62e9%16]) with mapi id\r\n 15.00.1178.000; Sun, 26 Jun 2016 16:30:51 -0600\r\n Content-Type: application/ms-tnef; name="winmail.dat"\r\n Content-Transfer-Encoding: binary\r\n From: Brian Shepard <Brian.Shepard@heatsoftware.com>\r\n To: Brendan Kelley\r\n <IMCEAEX-_O=GOLDMINE_OU=EXCHANGE+20ADMINISTRATIVE+20GROUP+20+28FYDIBOHF23SPDLT+29_CN=RECIPIENTS_CN=Brendan+20Kelley3ca@heatsoftware.com>\r\n Subject: FW: test\r\n Thread-Topic: test\r\n Thread-Index: AdHP+hvo/xvgCCQyQ6C9czTn1U0bjAAADqsw\r\n Date: Sun, 26 Jun 2016 16:30:51 -0600\r\n Message-ID: <81d0e65f9cfd4fcaac169c3098a8aa2f@cs-mbx01v.corp.lcl>\r\n Accept-Language: en-US\r\n Content-Language: en-US\r\n X-MS-Has-Attach: yes\r\n X-MS-TNEF-Correlator: <81d0e65f9cfd4fcaac169c3098a8aa2f@cs-mbx01v.corp.lcl>\r\n MIME-Version: 1.0\r\n X-MS-Exchange-Transport-FromEntityHeader: Hosted\r\n X-Originating-IP: [10.34.197.41]\r\n Return-Path: Brian.Shepard@heatsoftware.com'
#
# -------------
#
# 'Hello,\r\n IPCM ITSM down system pager number 719-278-7264 not routing to on call pager.\r\n Regards,\r\n Glenn Secrest\r\n Technical Analyst 2, \r\n Global Support Services\r\n o +1 719 278.7273\r\n w  www.ivanti.com\r\n Note: My new email address is: Glenn.Secrest@ivanti.com\r\n 8415 Explorer Drive, Suite 150 Colorado Springs, CO 80920\r\n This message is intended for the addressee(s) only and may contain confidential or privileged information. \r\n Any use of this information by persons other than addressee(s) is prohibited. \r\n If you have received this message in error, please reply to the sender and delete or destroy all copies. (AutoClosed)'
#
# -------------
#
# 'Test 7- Aug-2017'
#
# -------------
#
# 'Is this real?\r\n Ken\r\n From: Ivanti Security Team [mailto:mike.lloyd@ivanti.com] \r\n Sent: Sunday, April 2, 2017 9:02 PM\r\n To: Kenneth Folsom <Kenneth.Folsom@ivanti.com>\r\n Subject: You have been assigned Security Awareness Training\r\n Hi Kenneth,\r\n The Ivanti Security team is launching a new Password Training module for our security training initiative. We will be sharing educational tools that can assess and improve your security intelligence both at work and at home. You have an assignment awaiting your completion. You should be able to complete this training in approximately 10 - 20 minutes. Please click the link below to start your assignment, which is due by 04/28/2017.\r\n https://ivanti.securityeducation.com/ticketAuth/fe059c2eb93e4fb2a396770116680bda\r\n If you would like, you may review any of the other training modules available.\r\n If you have any questions or any feedback, please reach out to me at mike.lloyd@ivanti.com.\r\n Thank you,\r\n Mike Lloyd\r\n P.S. The URL for this training is assigned to you. Please do not share this link or email with other Ivanti employees. (AutoClosed)'
#
# -------------
#
# 'Hello Lina,\r\n I was able to get the site back up. Can you try to access the site again?\r\n Thank you,\r\n Matt\r\n From: Lina Liu [mailto:lina.liu@symbio.com] \r\n Sent: Sunday, December 20, 2015 9:25 PM\r\n To: Ming Lei <ming.lei@symbio.com>; IT Incidents <IT.Incidents@heatsoftware.com>\r\n Cc: Jason Holmes <Jason.Holmes@heatsoftware.com>; Patricia Jones <Patricia.Jones@heatsoftware.com>; Haihong Ma <haihong.ma@symbio.com>; Matt Wheeler <Matt.Wheeler@heatsoftware.com>; Kenneth Folsom <Kenneth.Folsom@heatsoftware.com>; Chris Andrew <Chris.Andrew@heatsoftware.com>\r\n Subject: RE: Can not login to the Test Vault\r\n Dear all,\r\n We also tried on a US machine and the issue is also reproduced. Who can help us to check it ASAP?\r\n Br,\r\n Lina\r\n From: Ming Lei \r\n Sent: Monday, December 21, 2015 12:06 PM\r\n To: IT.incidents\r\n Cc: Jason Holmes; Patricia Jones; Lina Liu; Haihong Ma; Matt.Wheeler\r\n Subject: Can not login to the Test Vault\r\n Hi,\r\n We are symbio team, we can login in TFS, but the error message “Internet Explorer cannot display the webpage” displayed when we try to login in TestVault, could you help us to check it? Thanks. The screenshot is attached.\r\n Symbio,\r\n Ming.Lei (AutoClosed)'
#
# -------------
#
# 'Incident was not created in Heat.\r\n From: jin.sun [mailto:jin.sun@symbio.com] \r\n Sent: Sunday, February 21, 2016 10:35 PM\r\n To: Matt Wheeler\r\n Cc: Jason Holmes; Patricia Jones; Lina Liu; haihong.ma@symbio.com; Ming Lei\r\n Subject: RE: TestVault issue\r\n Hi Matt,\r\n The TestVault issue is fixed, we can continue to run test cases. Thanks for your help.\r\n Good night!\r\n Jin\r\n From: Matt Wheeler [mailto:Matt.Wheeler@heatsoftware.com] \r\n Sent: 2016年2月22日 13:31\r\n To: Jin Sun\r\n Cc: Jason Holmes; Patricia Jones; Lina Liu; haihong.ma@symbio.com; Ming Lei\r\n Subject: RE: TestVault issue\r\n Hello Jin,\r\n I had to restart the IIS services on the TestVault app server. I was able to log into TestVault via Citrix.\r\n Can you have someone test it on your end?\r\n Thank you,\r\n Matt\r\n From: jin.sun [mailto:jin.sun@symbio.com] \r\n Sent: Sunday, February 21, 2016 10:14 PM\r\n To: IT Incidents\r\n Cc: Jason Holmes; Patricia Jones; Lina Liu; haihong.ma@symbio.com; Ming Lei; Matt Wheeler\r\n Subject: TestVault issue\r\n Hi,\r\n We are symbio team, we can’t access TestVault now, it is displayed blank page, but we can access TFS. Could you help us to check it? Thanks.\r\n Symbio,\r\n Jin Sun\r\n Disclaimer - This email and any attachments to it may be confidential and are intended solely for the use of the individual to whom it is addressed. Any views or opinions expressed are solely those of the author and do not necessarily represent those of the Company. If you are not the intended recipient of this email, you must neither take any action based upon its contents, nor copy or show it to anyone. Please contact the sender if you believe you have received this email in error. Please consider the environment and print this email/report only if necessary. \r\n Disclaimer - This email and any attachments to it may be confidential and are intended solely for the use of the individual to whom it is addressed. Any views or opinions expressed are solely those of the author and do not necessarily represent those of the Company. If you are not the intended recipient of this email, you must neither take any action based upon its contents, nor copy or show it to anyone. Please contact the sender if you believe you have received this email in error. Please consider the environment and print this email/report only if necessary. (AutoClosed)'
#
# -------------
#
# 'Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Ao (Jo) Shen \r\n Sent: Monday, October 9, 2017 11:26 AM\r\n To: Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>\r\n Subject: RE: Upload image to VMware cloud\r\n Hi Link,\r\n Permission is added! J\r\n Best regards,\r\n Jo Shen\r\n Technical Support Engineer\r\n e ao.shen@ivanti.com\r\n w www.ivanti.com\r\n From: Ao (Jo) Shen \r\n Sent: 2017年10月9日 10:53\r\n To: Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>\r\n Subject: Upload image to VMware cloud\r\n Hi Link,\r\n As discussed, could you please help upload this image to the VMware cloud storage location? Thanks so much!! J\r\n \\\\bej-sup-file\\Files\\Users\\Jo\\ct_windows_server_2016_x64_dvd_9718833.iso \r\n Best regards,\r\n Jo Shen\r\n Technical Support Engineer\r\n e ao.shen@ivanti.com\r\n w www.ivanti.com (AutoClosed)'
#
# -------------
#
# 'Added dns conditional forwarders.\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Andy Ng \r\n Sent: Monday, October 9, 2017 12:01 PM\r\n To: Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>; Brett Erickson <Brett.Erickson@ivanti.com>; Jeremy Balter <Jeremy.Balter@ivanti.com>; Jesse Bryce <Jesse.Bryce@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>; Andy Maynard <andy.maynard@ivanti.com>\r\n Subject: RE: Consolidated list of connectivity issues on the new office network\r\n Hi Link,\r\n I can confirm Issue 4 has been resolved.\r\n Andy Ng\r\n Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com\r\n From: Zhenhan (Link) Li \r\n Sent: Monday, October 9, 2017 11:26 AM\r\n To: Andy Ng <Andy.Ng@ivanti.com>; Brett Erickson <Brett.Erickson@ivanti.com>; Jeremy Balter <Jeremy.Balter@ivanti.com>; Jesse Bryce <Jesse.Bryce@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>; Andy Maynard <andy.maynard@ivanti.com>\r\n Subject: RE: Consolidated list of connectivity issues on the new office network\r\n Andy Ng,\r\n Issue 4 has been fixed.\r\n Jesse,\r\n Could you let me know what the dns servers are for domains plhost.global, qaplhost.local and devplhost.content.local? This way I can add related dns conditional forwarders on LD DCs. Thanks.\r\n 10.51.1.12 us-plh-14.plhost.global\r\n 10.12.41.13 sc-qaplh-02v.qaplhost.local\r\n 10.12.42.11 cdev-plh-03v.devplhost.content.local\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Andy Ng \r\n Sent: Thursday, October 5, 2017 1:15 PM\r\n To: Brett Erickson <Brett.Erickson@ivanti.com>; Jeremy Balter <Jeremy.Balter@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>; Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>\r\n Subject: RE: Consolidated list of connectivity issues on the new office network\r\n Hi Brett,\r\n Thanks for resolving issues 2 and 3 today.\r\n For issue 2, we are not able to access the Galway File Share: ie-fs-01v.lumension.lcl (10.5.10.13):\r\n For issue 3, we are not able to reach lum-prx.lumension.com on port 8088, and our EMSS agent is now Online: \r\n For issues 1 and 4, the internal DNS issues, we would wait for Jeremy or Link to add in the relevant DNS records when they are back.\r\n In the meantime, we are making do with adding the entries on the hosts file on our machines.\r\n Once again, thank you.\r\n Andy Ng\r\n Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com\r\n From: Brett Erickson \r\n Sent: Thursday, October 5, 2017 1:07 AM\r\n To: Jeremy Balter <Jeremy.Balter@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>; Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>; Andy Ng <Andy.Ng@ivanti.com>\r\n Subject: Re: Consolidated list of connectivity issues on the new office network\r\n Hey Jeremy, I have been assisting the guys over in Singapore to get things up and running for their new office. Can you assist us with line items 1 and 4 below? Thanks\r\n Brett Erickson\r\n Sr. Network Engineer\r\n o 801-208-1555\r\n m 435-757-4706\r\n brett.erickson@ivanti.com\r\n www.ivanti.com\r\n From: Andy Ng <Andy.Ng@ivanti.com>\r\n Date: Monday, October 2, 2017 at 2:13 AM\r\n To: "Zhenhan (Link) Li" <Zhenhan.Li@ivanti.com>, Brett Erickson <Brett.Erickson@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>, April Burrell <April.Burrell@ivanti.com>\r\n Subject: RE: Consolidated list of connectivity issues on the new office network\r\n Hi Brett,\r\n As Link is out of this office ...
#
# -------------
#
# 'test mail (AutoClosed)'
#
# -------------
#
# 'Ignore (AutoClosed)'
#
# -------------
#
# 'Hi Chris, I’ve changed my AppSense domain password this morning and also tried to change my LANDesk password. I had problems with the LANDesk password as this seemed to change it but then failed. I’m unable to change it / do anything as it thinks that my password has been changed too soon. If I look at the password details in password central for this then it looks like it has been changed but it hasn’t and doesn’t work. I can’t really get on to anything I need to at the moment, can this be reset through AD like last time?\r\n Regards\r\n Lyndon\r\n (AutoClosed)'
#
# -------------
#
# 'Good morning,\r\n Can you please contact me as soon as possible regarding this issue?\r\n Attached is the screen Michal gets when he boots his PC\r\n He is just back from holiday and nothing was done to the machine as far as we can tell\r\n Thank you for your help\r\n Benjamin Elzingre\r\n Technical Support Manager – EMEA\r\n Ivanti\r\n benjamin.elzingre@ivanti.com | www.heatsoftware.com | www.ivanti.com (AutoClosed)'
#
# -------------
#
# 'Morning Rob\r\n I hope you are well?\r\n I have tried to log in to my webex this morning and its locked me out a password reset isn’t working.\r\n Can you help?\r\n I have a conf call at 9.45am .\r\n Cheers\r\n Carmen \r\n '
#
# -------------
#
# 'Hi,\r\n I am getting the attached error when trying to sign in... my date and time are correct so not sure why it is giving this error?\r\n Thanks\r\n Roisin Ward\r\n Sales Development Representative\r\n Ivanti\r\n P: +35391422035\r\n roisin.ward@ivanti.com<mailto:roisin.ward@ivanti.com> | www.heatsoftware.com<http://www.heatsoftware.com/> | www.ivanti.com<http://www.ivanti.com/>\r\n [cid:image007.jpg@01D275A7.AD1D1C00]\r\n [Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: FrontRange on Facebook]<http://www.facebook.com/frontrange> [Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: FrontRange twitter] <http://www.twitter.com/frontrange>  [Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: FrontRange YouTube] <http://www.youtube.com/frontrange>  [Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: Description: FrontRange on LinkedIn] <http://www.linkedin.com/companies/frontrange-solutions>\r\n [ISO9001Reg-2cm-Col] (AutoClosed)'
#
# -------------
#
# 'Dear all\r\n My WebEx account is deactivated – how can my account get activated ?\r\n Ulrich Gaukel\r\n HEAT Service Management Support Analyst.\r\n x7119\r\n ulrich.gaukel@heatsoftware.com | www.HEATsoftware.com\r\n Address and company information at: http://heatsoftware.com/frontrange-support-contact-information (AutoClosed)'
#
# -------------
#
# 'Dear All,\r\n Can you please provide me credential to https://sftp.lumension.com?\r\n I’d like to download LanRev image created by Brett Chadwick \r\n Thanks in advance.\r\n Mit freundlichen Grüßen / Best Regards,\r\n Marek Woda, PhD\r\n Senior Solutions Engineer / ITIL v3 certified\r\n P: +49 (89) 3188 3440 |Mobile: +48 606 820 585\r\n marek.woda@heatsoftware.com| www.HEATsoftware.com\r\n HEAT Software Deutschland GmbH | Carl-von-Linde Strasse 38 | 85716 Unterschleißheim | Germany\r\n Management Board: John Ferron, M. Arantzazu Baudet Garcia. Register Court: AG - München. Commercial Register Number: HRB 13 01 11. Value added tax identification number: DE 206 863 402.\r\n Confidentiality Note: This email message is for the sole use of the intended recipient(s) and may contain confidential and legally privileged information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please contact the sender by reply email and destroy all copies of the original message. (AutoClosed)'
#
# -------------
#
# 'Hello IT, \r\n I am unable to log into the dashboard, even though I updated the settings as outlined in the document:\r\n - Using the same username as before and ‘password’ – as outlined in the documentation.\r\n Thanks, \r\n Petra (AutoClosed)'
#
# -------------
#
# 'Hello\r\n I am not able to log into the new IVR Server: GCO-SIP01v.corp.lcl\r\n I get an error message: Invalid username or password.\r\n See screenshot:\r\n Regards\r\n Martin\r\n Martin Nabbs\r\n Senior Support Analyst\r\n FrontRange is now HEAT Software \r\n Read about our merger with Lumension here \r\n P: +44 (0)843 378 0042\r\n PremiseServiceManagement.support@frontrange.com | www.frontrange.com\r\n Registered in England & Wales: 3794908\r\n This message is intended for the addressee(s) only and may contain confidential or privileged information. Any use of this information by persons other than addressee(s) is prohibited. If you have received this message in error, please reply to the sender and delete or destroy all copies (AutoClosed)'
#
# -------------
#
# 'Morning,\r\n Can you please switch the UK sales hunt number back over to me this morning as I have now returned from leave.\r\n 091 422035\r\n Thanks\r\n Roisin Ward\r\n Sales Development Representative\r\n roisin.ward@heatsoftware.com\r\n 00353 91 422035 (AutoClosed)'
#
# -------------

# %%
input_df['Symptom'] = input_df['Symptom'].replace(regex='(\r\n(\\s+)?)+',value='\r\n ')

# %%
input_df['Symptom'][1163]
# Out:
# 'Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Zhenhan (Link) Li \r\n Sent: Thursday, September 28, 2017 11:13 AM\r\n To: Andy Maynard <andy.maynard@ivanti.com>\r\n Cc: Adam Jones <Adam.Jones@ivanti.com>\r\n Subject: FW: Cannot resolve cs.vpn.heatsoftware.com on the new corporate network\r\n Andy,\r\n Network latency between bej and Singapore is big so 172.27.0.250 and 172.28.0.250 act as dns servers for Singapore office, but these two dns servers can’t resolve hostnames below. After double checking, heat dns server 10.101.25.101, 10.101.25.102 didn’t have records for them so I added them as below(highlighted ones).\r\n B Added conditional forwarders for vpn.heatsoftware.com on 172.27.0.250 and 172.28.0.250 servers\r\n Added Hostnames:\r\n cs.vpn.heatsoftware.com\r\n mu.vpn.heatsoftware.com\r\n sy.vpn.heatsoftware.com\r\n uk.vpn.heatsoftware.com\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Zhenhan (Link) Li \r\n Sent: Thursday, September 28, 2017 11:01 AM\r\n To: Andy Ng <Andy.Ng@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>\r\n Subject: RE: Cannot resolve cs.vpn.heatsoftware.com on the new corporate network\r\n Ok, added this records too.\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n From: Andy Ng \r\n Sent: Thursday, September 28, 2017 9:42 AM\r\n To: Zhenhan (Link) Li <Zhenhan.Li@ivanti.com>\r\n Cc: Leonard Cheong <Leonard.Cheong@ivanti.com>; April Burrell <April.Burrell@ivanti.com>\r\n Subject: RE: Cannot resolve cs.vpn.heatsoftware.com on the new corporate network\r\n Hi Link,\r\n Could you also fix the other VPN hostnames? \r\n They are:\r\n mu.vpn.heatsoftware.com\r\n sy.vpn.heatsoftware.com\r\n uk.vpn.heatsoftware.com\r\n Thanks.\r\n C:\\Windows\\system32>ping cs.vpn.heatsoftware.com\r\n Pinging cs.vpn.heatsoftware.com [206.104.144.8] with 32 bytes of data:\r\n Reply from 206.104.144.8: bytes=32 time=255ms TTL=239\r\n Reply from 206.104.144.8: bytes=32 time=249ms TTL=239\r\n Reply from 206.104.144.8: bytes=32 time=251ms TTL=239\r\n Reply from 206.104.144.8: bytes=32 time=247ms TTL=239\r\n Ping statistics for 206.104.144.8:\r\n Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),\r\n Approximate round trip times in milli-seconds:\r\n Minimum = 247ms, Maximum = 255ms, Average = 250ms\r\n C:\\Windows\\system32>ping ca.vpn.heatsoftware.com\r\n Pinging ca.vpn.heatsoftware.com [65.123.15.2] with 32 bytes of data:\r\n Reply from 65.123.15.2: bytes=32 time=181ms TTL=240\r\n Reply from 65.123.15.2: bytes=32 time=171ms TTL=242\r\n Reply from 65.123.15.2: bytes=32 time=181ms TTL=240\r\n Reply from 65.123.15.2: bytes=32 time=182ms TTL=242\r\n Ping statistics for 65.123.15.2:\r\n Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),\r\n Approximate round trip times in milli-seconds:\r\n Minimum = 171ms, Maximum = 182ms, Average = 178ms\r\n C:\\Windows\\system32>ping fs.vpn.heatsoftware.com\r\n Pinging fs.vpn.heatsoftware.com [188.111.57.2] with 32 bytes of data:\r\n Reply from 188.111.57.2: bytes=32 time=284ms TTL=238\r\n Reply from 188.111.57.2: bytes=32 time=284ms TTL=238\r\n Reply from 188.111.57.2: bytes=32 time=284ms TTL=238\r\n Reply from 188.111.57.2: bytes=32 time=284ms TTL=238\r\n Ping statistics for 188.111.57.2:\r\n Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),\r\n Approximate round trip times in milli-seconds:\r\n Minimum = 284ms, Maximum = 284ms, Average = 284ms\r\n C:\\Windows\\system32>ping mu.vpn.heatsoftware.com\r\n Ping request could not find host mu.vpn.heatsoftware.com. Please check the name and try again.\r\n C:\\Windows\\system32>ping sy.vpn.h ...

# %%
a = input_df['Symptom'].str.contains("Andy Ng\r\n Technical Support ")
a[ a == True ]
# Out:
# 8        True
# 1163     True
# 2601     True
# 2897     True
# 2899     True
# 4646     True
# 5634     True
# 5860     True
# 6090     True
# 6125     True
# 6188     True
# 6606     True
# 7303     True
# 7601     True
# 7688     True
# 7701     True
# 7702     True
# 7931     True
# 8580     True
# 9325     True
# 10038    True
# 10051    True
# 10501    True
# 11227    True
# Name: Symptom, dtype: bool

# %%
input_df['Symptom'] = input_df['Symptom'].replace(regex='(\r\n(\\s+)?)+',value='\r\n ')
input_df['Symptom'] = input_df['Symptom'].replace(regex=["\\sFrom:.*\\s",
                        "\\sTo:.*\\s","\\sDate:.*\\s","\\sSubject:.*\\s","\\sSent:.*\\s",
                        "\\sCc:.*\\s","\\sBcc:\\s"], value='')
input_df['Symptom'] = input_df['Symptom'].replace(regex=[                                                         
                        "(?s)\\sThis message is intended .* destroy all copies\\.?\\s",
                        "(?s)\\sDisclaimer .* only if necessary\\.?\\s",
                        "(?s)\\sConfidentiality Note:.*original message\\.?\\s"], value='')
input_df['Symptom'] = input_df['Symptom'].replace(regex='\\s?\\(AutoClosed\\)', value = '')

# %%
count = 0
index = []
for i in range(input_df.shape[0]):
    if len(input_df['Symptom'][i]) > 3000:
        count+=1
        index.append(i)
#         print(input_df['Symptom'][i])
#         print("\n-------------\n")

print(count)
print(index)
# Out:
# 338
# [8, 59, 147, 186, 220, 263, 275, 329, 336, 346, 397, 467, 494, 496, 532, 534, 538, 691, 725, 791, 800, 840, 843, 876, 894, 911, 955, 966, 987, 1123, 1163, 1186, 1199, 1247, 1281, 1339, 1346, 1439, 1489, 1509, 1510, 1515, 1566, 1595, 1611, 1631, 1757, 1759, 1778, 1806, 1814, 1824, 1868, 1869, 1879, 1881, 1884, 1886, 1889, 2037, 2058, 2060, 2114, 2120, 2147, 2285, 2402, 2403, 2406, 2425, 2442, 2468, 2473, 2480, 2579, 2591, 2609, 2621, 2676, 2720, 2736, 2746, 2814, 2824, 2856, 2871, 2873, 3051, 3202, 3309, 3429, 3491, 3492, 3629, 3710, 3800, 3840, 3876, 3976, 4000, 4005, 4022, 4023, 4079, 4168, 4241, 4242, 4397, 4459, 4461, 4487, 4513, 4550, 4551, 4562, 4563, 4651, 4713, 4744, 4755, 4769, 4783, 4788, 4813, 4895, 4918, 4939, 4946, 5008, 5059, 5082, 5131, 5159, 5167, 5222, 5249, 5282, 5296, 5303, 5327, 5375, 5385, 5402, 5461, 5571, 5656, 5666, 5728, 5745, 5829, 5838, 5866, 5867, 5875, 5897, 5901, 5961, 6063, 6095, 6098, 6154, 6166, 6222, 6249, 6251, 6262, 6265, 6319, 6328, 6402, 6430, 6470, 6487, 6500, 6508, 6549, 6574, 6577, 6598, 6629, 6633, 6668, 6690, 6718, 6759, 6777, 6793, 6794, 6845, 6851, 6869, 6896, 6903, 6931, 7016, 7062, 7152, 7177, 7199, 7204, 7235, 7279, 7321, 7355, 7414, 7522, 7527, 7645, 7709, 7764, 7789, 7829, 7871, 7893, 7910, 7920, 7967, 7990, 8000, 8030, 8098, 8108, 8120, 8168, 8243, 8244, 8245, 8403, 8406, 8407, 8441, 8496, 8515, 8552, 8562, 8596, 8612, 8655, 8656, 8661, 8684, 8714, 8718, 8751, 8753, 8757, 8771, 8799, 8804, 8807, 8814, 8825, 8837, 8839, 8842, 8855, 8868, 8899, 8902, 8906, 8928, 8932, 8956, 8971, 8985, 9019, 9023, 9042, 9068, 9096, 9129, 9154, 9200, 9219, 9233, 9240, 9270, 9281, 9321, 9367, 9438, 9459, 9659, 9735, 9738, 9743, 9771, 9804, 9826, 9888, 9923, 9938, 9974, 10007, 10022, 10047, 10052, 10056, 10071, 10078, 10117, 10120, 10168, 10183, 10199, 10252, 10253, 10257, 10336, 10337, 10338, 10341, 10365, 10378, 10425, 10458, 10489, 10517, 10572, 10666, 10787, 10788, 10806, 10824, 10854, 10868, 10927, 10950, 10988, 11026, 11108, 11143, 11175, 11187, 11208, 11209, 11225, 11233]

# %%
print(input_df['Symptom'][5249])
# Out:
# The lab manager may be crashed. I get the following connecting to https://fs-vcd/cloud/org/tso/:
#  HTTP ERROR 500
#  Problem accessing /cloud/org/tso/. Reason:
#  Server Error
#  Caused by:
#  com.vmware.vcloud.common.persist.exception.CellNotActiveException: Cell is not active
#  at com.vmware.vcloud.common.persist.impl.CellLivenessStatusServiceImpl.validateIsActive(CellLivenessStatusServiceImpl.java:128)
#  at com.vmware.vcloud.common.persist.QueryInterceptor.validateIsActive(QueryInterceptor.java:113)
#  at com.vmware.vcloud.common.persist.QueryInterceptor.onPrepareStatement(QueryInterceptor.java:145)
#  at org.hibernate.jdbc.AbstractBatcher.getSQL(AbstractBatcher.java:488)
#  at org.hibernate.jdbc.AbstractBatcher.getPreparedStatement(AbstractBatcher.java:510)
#  at org.hibernate.jdbc.AbstractBatcher.getPreparedStatement(AbstractBatcher.java:452)
#  at org.hibernate.jdbc.AbstractBatcher.prepareQueryStatement(AbstractBatcher.java:161)
#  at org.hibernate.loader.Loader.prepareQueryStatement(Loader.java:1573)
#  at org.hibernate.loader.Loader.doQuery(Loader.java:696)
#  at org.hibernate.loader.Loader.doQueryAndInitializeNonLazyCollections(Loader.java:259)
#  at org.hibernate.loader.Loader.doList(Loader.java:2228)
#  at org.hibernate.loader.Loader.listIgnoreQueryCache(Loader.java:2125)
#  at org.hibernate.loader.Loader.list(Loader.java:2120)
#  at org.hibernate.loader.criteria.CriteriaLoader.list(CriteriaLoader.java:118)
#  at org.hibernate.impl.SessionImpl.list(SessionImpl.java:1596)
#  at org.hibernate.impl.CriteriaImpl.list(CriteriaImpl.java:306)
#  at org.hibernate.impl.CriteriaImpl.uniqueResult(CriteriaImpl.java:328)
#  at com.vmware.vcloud.common.persist.CriteriaProxy.uniqueResult(CriteriaProxy.java:212)
#  at com.vmware.ssdc.backendbase.dao.impl.HibernateOrganizationDao.findByName(HibernateOrganizationDao.java:98)
#  at com.vmware.ssdc.backendbase.dao.impl.HibernateOrganizationDao.findOrgByName(HibernateOrganizationDao.java:80)
#  at com.vmware.ssdc.backendbase.OrganizationFactory.GetOrg(OrganizationFactory.java:65)
#  at com.vmware.ssdc.backendbase.CSecurityManager.findOrg(CSecurityManager.java:1351)
#  at sun.reflect.GeneratedMethodAccessor4968.invoke(Unknown Source)
#  at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
#  at java.lang.reflect.Method.invoke(Method.java:606)
#  at org.springframework.aop.support.AopUtils.invokeJoinpointUsingReflection(AopUtils.java:319)
#  at org.springframework.osgi.service.importer.support.internal.aop.ServiceInvoker.doInvoke(ServiceInvoker.java:58)
#  at org.springframework.osgi.service.importer.support.internal.aop.ServiceInvoker.invoke(ServiceInvoker.java:62)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.doProceed(DelegatingIntroductionInterceptor.java:131)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.invoke(DelegatingIntroductionInterceptor.java:119)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.osgi.service.util.internal.aop.ServiceTCCLInterceptor.invokeUnprivileged(ServiceTCCLInterceptor.java:56)
#  at org.springframework.osgi.service.util.internal.aop.ServiceTCCLInterceptor.invoke(ServiceTCCLInterceptor.java:39)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.osgi.service.importer.support.LocalBundleContextAdvice.invoke(LocalBundleContextAdvice.java:59)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.doProceed(DelegatingIntroductionInterceptor.java:131)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.invoke(DelegatingIntroductionInterceptor.java:119)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.framework.JdkDynamicAopProxy.invoke(JdkDynamicAopProxy.java:202)
#  at com.sun.proxy.$Proxy1051.findOrg(Unknown Source)
#  at com.vmware.vcloud.spring.bridge.CloudTenantProvider.loadTenant(CloudTenantProvider.java:37)
#  at com.vmware.spring.security.multitenancy.web.AbstractMultitenancyStrategy.determineTenant(AbstractMultitenancyStrategy.java:59)
#  at com.vmware.spring.security.multitenancy.web.MultitenantRequestFilter.applyStrategy(MultitenantRequestFilter.java:104)
#  at com.vmware.spring.security.multitenancy.web.MultitenantRequestFilter.doFilterInternal(MultitenantRequestFilter.java:116)
#  at org.springframework.web.filter.OncePerRequestFilter.doFilter(OncePerRequestFilter.java:76)
#  at org.springframework.security.web.FilterChainProxy$VirtualFilterChain.doFilter(FilterChainProxy.java:342)
#  at org.springframework.security.web.FilterChainProxy.doFilterInternal(FilterChainProxy.java:192)
#  at org.springframework.security.web.FilterChainProxy.doFilter(FilterChainProxy.java:160)
#  at org.springframework.web.filter.DelegatingFilterProxy.invokeDelegate(DelegatingFilterProxy.java:346)
#  at org.springframework.web.filter.DelegatingFilterProxy.doFilter(DelegatingFilterProxy.java:259)
#  at org.eclipse.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1476)
#  at com.vmware.vcloud.common.web.deployment.impl.RequestDiagnosticFilter.doFilter(RequestDiagnosticFilter.java:64)
#  at org.eclipse.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1467)
#  at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:501)
#  at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:137)
#  at org.eclipse.jetty.security.SecurityHandler.handle(SecurityHandler.java:557)
#  at org.eclipse.jetty.server.session.SessionHandler.doHandle(SessionHandler.java:231)
#  at org.eclipse.jetty.server.handler.ContextHandler.doHandle(ContextHandler.java:1086)
#  at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:429)
#  at org.eclipse.jetty.server.session.SessionHandler.doScope(SessionHandler.java:193)
#  at org.eclipse.jetty.server.handler.ContextHandler.doScope(ContextHandler.java:1020)
#  at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:135)
#  at org.eclipse.jetty.server.handler.ContextHandlerCollection.handle(ContextHandlerCollection.java:255)
#  at org.eclipse.jetty.server.handler.HandlerList.handle(HandlerList.java:52)
#  at org.eclipse.jetty.server.handler.HandlerCollection.handle(HandlerCollection.java:154)
#  at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:116)
#  at org.eclipse.jetty.server.Server.handle(Server.java:370)
#  at org.eclipse.jetty.server.AbstractHttpConnection.handleRequest(AbstractHttpConnection.java:494)
#  at org.eclipse.jetty.server.AbstractHttpConnection.headerComplete(AbstractHttpConnection.java:971)
#  at org.eclipse.jetty.server.AbstractHttpConnection$RequestHandler.headerComplete(AbstractHttpConnection.java:1033)
#  at org.eclipse.jetty.http.HttpParser.parseNext(HttpParser.java:644)
#  at org.eclipse.jetty.http.HttpParser.parseAvailable(HttpParser.java:235)
#  at org.eclipse.jetty.server.AsyncHttpConnection.handle(AsyncHttpConnection.java:82)
#  at org.eclipse.jetty.io.nio.SslConnection.handle(SslConnection.java:196)
#  at org.eclipse.jetty.io.nio.SelectChannelEndPoint.handle(SelectChannelEndPoint.java:696)
#  at org.eclipse.jetty.io.nio.SelectChannelEndPoint$1.run(SelectChannelEndPoint.java:53)
#  at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:608)
#  at org.eclipse.jetty.util.thread.QueuedThreadPool$3.run(QueuedThreadPool.java:543)
#  at java.lang.Thread.run(Thread.java:745)
#  Powered by Jetty://
#  Regards,
#  Jason Shafer
#  UEM Security and Client Management Technical Lead
#  HEAT Software (Formerly FrontRange)
#  P: +1 800.755.2100
#  Jason.shafer@frontrange.com | www.HEATsoftware.com

# %%
# for i in range(20):
#     print(re.findall("\\sDiagnostic information for administrators\\s", input_df['Symptom'][i]))
# #     print("\n" + input_df['Subject'][i])
#     print("\n-------------\n")

count = 0
index =[]
for j in range(input_df.shape[0]):
    if len(re.findall("o:", input_df['Symptom'][j])) > 0:
        index.append(j)
        count+=1
        
print(count)
print(index)
# Out:
# 698
# [14, 59, 113, 114, 117, 118, 135, 172, 194, 197, 198, 224, 263, 346, 364, 376, 397, 398, 423, 426, 444, 460, 534, 556, 575, 578, 580, 588, 597, 607, 634, 691, 696, 706, 713, 768, 776, 784, 786, 787, 791, 796, 808, 821, 843, 850, 865, 868, 876, 894, 896, 911, 934, 939, 980, 1076, 1129, 1131, 1142, 1149, 1181, 1186, 1198, 1199, 1205, 1216, 1247, 1258, 1260, 1306, 1360, 1397, 1409, 1433, 1438, 1439, 1463, 1468, 1483, 1575, 1650, 1655, 1665, 1738, 1740, 1778, 1824, 1825, 1836, 1839, 1848, 1849, 1895, 1925, 1948, 1953, 1965, 1991, 1992, 2010, 2023, 2051, 2068, 2092, 2094, 2120, 2150, 2158, 2167, 2195, 2212, 2246, 2356, 2358, 2402, 2403, 2404, 2406, 2408, 2425, 2426, 2434, 2435, 2442, 2457, 2465, 2467, 2477, 2480, 2491, 2591, 2621, 2637, 2645, 2671, 2687, 2705, 2709, 2714, 2736, 2737, 2766, 2768, 2798, 2814, 2837, 2838, 2845, 2869, 2871, 2887, 2902, 2907, 3020, 3023, 3035, 3062, 3070, 3077, 3115, 3180, 3202, 3209, 3216, 3374, 3400, 3401, 3451, 3452, 3455, 3457, 3482, 3491, 3492, 3501, 3522, 3533, 3603, 3616, 3618, 3628, 3629, 3650, 3657, 3673, 3700, 3722, 3725, 3770, 3772, 3773, 3799, 3800, 3842, 3876, 3880, 3903, 3908, 3934, 3952, 3968, 3976, 3985, 3999, 4047, 4050, 4067, 4069, 4079, 4089, 4149, 4168, 4189, 4190, 4229, 4238, 4241, 4242, 4252, 4254, 4256, 4277, 4313, 4314, 4315, 4316, 4393, 4395, 4400, 4407, 4408, 4426, 4449, 4459, 4466, 4513, 4532, 4550, 4551, 4561, 4580, 4589, 4612, 4617, 4639, 4651, 4677, 4686, 4698, 4706, 4738, 4744, 4755, 4758, 4769, 4788, 4789, 4813, 4867, 4890, 4893, 4895, 4899, 4916, 4918, 4926, 4939, 4941, 4972, 5016, 5017, 5026, 5038, 5046, 5050, 5073, 5082, 5101, 5131, 5142, 5144, 5167, 5198, 5214, 5221, 5229, 5230, 5232, 5282, 5285, 5291, 5303, 5314, 5317, 5333, 5336, 5365, 5368, 5385, 5388, 5402, 5423, 5426, 5470, 5483, 5500, 5522, 5554, 5558, 5563, 5567, 5574, 5616, 5620, 5630, 5641, 5679, 5703, 5705, 5716, 5726, 5794, 5829, 5834, 5860, 5866, 5867, 5872, 5874, 5897, 5901, 5938, 5953, 5961, 6011, 6037, 6050, 6095, 6098, 6128, 6154, 6166, 6251, 6255, 6258, 6262, 6283, 6319, 6328, 6375, 6415, 6435, 6442, 6458, 6461, 6462, 6474, 6487, 6494, 6497, 6500, 6508, 6526, 6536, 6539, 6547, 6561, 6598, 6619, 6629, 6633, 6656, 6665, 6671, 6741, 6742, 6760, 6762, 6793, 6813, 6835, 6894, 6931, 6941, 6961, 6981, 7002, 7003, 7026, 7032, 7083, 7090, 7102, 7120, 7124, 7129, 7152, 7155, 7159, 7180, 7181, 7182, 7196, 7204, 7214, 7228, 7230, 7233, 7241, 7253, 7301, 7317, 7321, 7343, 7355, 7361, 7369, 7409, 7419, 7469, 7478, 7497, 7513, 7521, 7522, 7527, 7546, 7572, 7634, 7636, 7643, 7645, 7687, 7709, 7730, 7743, 7763, 7774, 7788, 7789, 7800, 7807, 7859, 7860, 7872, 7893, 7910, 7917, 7947, 7967, 7971, 7985, 7990, 8002, 8007, 8008, 8017, 8030, 8043, 8062, 8064, 8098, 8108, 8120, 8126, 8168, 8188, 8196, 8201, 8234, 8240, 8271, 8305, 8346, 8357, 8367, 8369, 8395, 8406, 8413, 8414, 8441, 8496, 8527, 8531, 8534, 8542, 8562, 8577, 8583, 8595, 8596, 8597, 8612, 8617, 8628, 8630, 8655, 8656, 8661, 8669, 8684, 8685, 8699, 8702, 8718, 8753, 8768, 8771, 8777, 8799, 8804, 8814, 8837, 8842, 8855, 8864, 8867, 8868, 8894, 8899, 8902, 8906, 8910, 8919, 8922, 8958, 8971, 8978, 8985, 8996, 9019, 9023, 9074, 9082, 9104, 9118, 9127, 9129, 9154, 9161, 9162, 9200, 9216, 9223, 9226, 9231, 9233, 9240, 9247, 9257, 9273, 9305, 9315, 9335, 9342, 9348, 9360, 9373, 9385, 9400, 9429, 9434, 9438, 9441, 9444, 9454, 9462, 9468, 9479, 9509, 9527, 9529, 9538, 9557, 9602, 9616, 9647, 9654, 9659, 9663, 9666, 9687, 9743, 9747, 9759, 9766, 9771, 9790, 9843, 9846, 9858, 9873, 9924, 9931, 9932, 9968, 9974, 9984, 10007, 10012, 10018, 10022, 10025, 10046, 10047, 10051, 10052, 10054, 10056, 10071, 10098, 10107, 10113, 10120, 10137, 10147, 10164, 10168, 10174, 10180, 10192, 10208, 10221, 10226, 10252, 10253, 10257, 10283, 10284, 10288, 10318, 10321, 10332, 10336, 10337, 10341, 10342, 10367, 10372, 10378, 10394, 10395, 10399, 10422, 10431, 10455, 10472, 10473, 10489, 10494, 10509, 10529, 10572, 10605, 10639, 10648, 10657, 10659, 10664, 10689, 10697, 10699, 10720, 10766,  ...

# %%
message = """Good morning,
 
 
 
Can you please contact me as soon as possible regarding this issue?
 
Attached is the screen Michal gets when he boots his PC
 
He is just back from holiday and nothing was done to the machine as far as we can tell
 
 
 
Thank you for your help,
 
Benjamin Elzingre
Technical Support Manager – EMEA
Ivanti
benjamin.elzingre@ivanti.com | www.heatsoftware.com | www.ivanti.com (AutoClosed)
 """

# %%
import email
b = email.message_from_string(message)
print(b)
# Out:
# The lab manager may be crashed. I get the following connecting to https://fs-vcd/cloud/org/tso/:
#  HTTP ERROR 500
#  Problem accessing /cloud/org/tso/. Reason:
#  Server Error
#  Caused by:
#  com.vmware.vcloud.common.persist.exception.CellNotActiveException: Cell is not active
#  at com.vmware.vcloud.common.persist.impl.CellLivenessStatusServiceImpl.validateIsActive(CellLivenessStatusServiceImpl.java:128)
#  at com.vmware.vcloud.common.persist.QueryInterceptor.validateIsActive(QueryInterceptor.java:113)
#  at com.vmware.vcloud.common.persist.QueryInterceptor.onPrepareStatement(QueryInterceptor.java:145)
#  at org.hibernate.jdbc.AbstractBatcher.getSQL(AbstractBatcher.java:488)
#  at org.hibernate.jdbc.AbstractBatcher.getPreparedStatement(AbstractBatcher.java:510)
#  at org.hibernate.jdbc.AbstractBatcher.getPreparedStatement(AbstractBatcher.java:452)
#  at org.hibernate.jdbc.AbstractBatcher.prepareQueryStatement(AbstractBatcher.java:161)
#  at org.hibernate.loader.Loader.prepareQueryStatement(Loader.java:1573)
#  at org.hibernate.loader.Loader.doQuery(Loader.java:696)
#  at org.hibernate.loader.Loader.doQueryAndInitializeNonLazyCollections(Loader.java:259)
#  at org.hibernate.loader.Loader.doList(Loader.java:2228)
#  at org.hibernate.loader.Loader.listIgnoreQueryCache(Loader.java:2125)
#  at org.hibernate.loader.Loader.list(Loader.java:2120)
#  at org.hibernate.loader.criteria.CriteriaLoader.list(CriteriaLoader.java:118)
#  at org.hibernate.impl.SessionImpl.list(SessionImpl.java:1596)
#  at org.hibernate.impl.CriteriaImpl.list(CriteriaImpl.java:306)
#  at org.hibernate.impl.CriteriaImpl.uniqueResult(CriteriaImpl.java:328)
#  at com.vmware.vcloud.common.persist.CriteriaProxy.uniqueResult(CriteriaProxy.java:212)
#  at com.vmware.ssdc.backendbase.dao.impl.HibernateOrganizationDao.findByName(HibernateOrganizationDao.java:98)
#  at com.vmware.ssdc.backendbase.dao.impl.HibernateOrganizationDao.findOrgByName(HibernateOrganizationDao.java:80)
#  at com.vmware.ssdc.backendbase.OrganizationFactory.GetOrg(OrganizationFactory.java:65)
#  at com.vmware.ssdc.backendbase.CSecurityManager.findOrg(CSecurityManager.java:1351)
#  at sun.reflect.GeneratedMethodAccessor4968.invoke(Unknown Source)
#  at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
#  at java.lang.reflect.Method.invoke(Method.java:606)
#  at org.springframework.aop.support.AopUtils.invokeJoinpointUsingReflection(AopUtils.java:319)
#  at org.springframework.osgi.service.importer.support.internal.aop.ServiceInvoker.doInvoke(ServiceInvoker.java:58)
#  at org.springframework.osgi.service.importer.support.internal.aop.ServiceInvoker.invoke(ServiceInvoker.java:62)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.doProceed(DelegatingIntroductionInterceptor.java:131)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.invoke(DelegatingIntroductionInterceptor.java:119)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.osgi.service.util.internal.aop.ServiceTCCLInterceptor.invokeUnprivileged(ServiceTCCLInterceptor.java:56)
#  at org.springframework.osgi.service.util.internal.aop.ServiceTCCLInterceptor.invoke(ServiceTCCLInterceptor.java:39)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.osgi.service.importer.support.LocalBundleContextAdvice.invoke(LocalBundleContextAdvice.java:59)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.doProceed(DelegatingIntroductionInterceptor.java:131)
#  at org.springframework.aop.support.DelegatingIntroductionInterceptor.invoke(DelegatingIntroductionInterceptor.java:119)
#  at org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:172)
#  at org.springframework.aop.framework.JdkDynamicAopProxy.invoke(JdkDynamicAopProxy.java:202)
#  at com.sun.proxy.$Proxy1051.findOrg(Unknown Source)
#  at com.vmware.vcloud.spring.bridge.CloudTenantProvider.loadTenant(CloudTenantProvider.java:37)
#  at com.vmware.spring.security.multitenancy.web.AbstractMultitenancyStrategy.determineTenant(AbstractMultitenancyStrategy.java:59)
#  at com.vmware.spring.security.multitenancy.web.MultitenantRequestFilter.applyStrategy(MultitenantRequestFilter.java:104)
#  at com.vmware.spring.security.multitenancy.web.MultitenantRequestFilter.doFilterInternal(MultitenantRequestFilter.java:116)
#  at org.springframework.web.filter.OncePerRequestFilter.doFilter(OncePerRequestFilter.java:76)
#  at org.springframework.security.web.FilterChainProxy$VirtualFilterChain.doFilter(FilterChainProxy.java:342)
#  at org.springframework.security.web.FilterChainProxy.doFilterInternal(FilterChainProxy.java:192)
#  at org.springframework.security.web.FilterChainProxy.doFilter(FilterChainProxy.java:160)
#  at org.springframework.web.filter.DelegatingFilterProxy.invokeDelegate(DelegatingFilterProxy.java:346)
#  at org.springframework.web.filter.DelegatingFilterProxy.doFilter(DelegatingFilterProxy.java:259)
#  at org.eclipse.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1476)
#  at com.vmware.vcloud.common.web.deployment.impl.RequestDiagnosticFilter.doFilter(RequestDiagnosticFilter.java:64)
#  at org.eclipse.jetty.servlet.ServletHandler$CachedChain.doFilter(ServletHandler.java:1467)
#  at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:501)
#  at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:137)
#  at org.eclipse.jetty.security.SecurityHandler.handle(SecurityHandler.java:557)
#  at org.eclipse.jetty.server.session.SessionHandler.doHandle(SessionHandler.java:231)
#  at org.eclipse.jetty.server.handler.ContextHandler.doHandle(ContextHandler.java:1086)
#  at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:429)
#  at org.eclipse.jetty.server.session.SessionHandler.doScope(SessionHandler.java:193)
#  at org.eclipse.jetty.server.handler.ContextHandler.doScope(ContextHandler.java:1020)
#  at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:135)
#  at org.eclipse.jetty.server.handler.ContextHandlerCollection.handle(ContextHandlerCollection.java:255)
#  at org.eclipse.jetty.server.handler.HandlerList.handle(HandlerList.java:52)
#  at org.eclipse.jetty.server.handler.HandlerCollection.handle(HandlerCollection.java:154)
#  at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:116)
#  at org.eclipse.jetty.server.Server.handle(Server.java:370)
#  at org.eclipse.jetty.server.AbstractHttpConnection.handleRequest(AbstractHttpConnection.java:494)
#  at org.eclipse.jetty.server.AbstractHttpConnection.headerComplete(AbstractHttpConnection.java:971)
#  at org.eclipse.jetty.server.AbstractHttpConnection$RequestHandler.headerComplete(AbstractHttpConnection.java:1033)
#  at org.eclipse.jetty.http.HttpParser.parseNext(HttpParser.java:644)
#  at org.eclipse.jetty.http.HttpParser.parseAvailable(HttpParser.java:235)
#  at org.eclipse.jetty.server.AsyncHttpConnection.handle(AsyncHttpConnection.java:82)
#  at org.eclipse.jetty.io.nio.SslConnection.handle(SslConnection.java:196)
#  at org.eclipse.jetty.io.nio.SelectChannelEndPoint.handle(SelectChannelEndPoint.java:696)
#  at org.eclipse.jetty.io.nio.SelectChannelEndPoint$1.run(SelectChannelEndPoint.java:53)
#  at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:608)
#  at org.eclipse.jetty.util.thread.QueuedThreadPool$3.run(QueuedThreadPool.java:543)
#  at java.lang.Thread.run(Thread.java:745)
#  Powered by Jetty://
#  Regards,
#  Jason Shafer
#  UEM Security and Client Management Technical Lead
#  HEAT Software (Formerly FrontRange)
#  P: +1 800.755.2100
#  Jason.shafer@frontrange.com | www.HEATsoftware.com

# %%
import talon
from talon import quotations
talon.init()
from talon import signature
from talon.signature.bruteforce import extract_signature

kunal =  input_df['Symptom'].apply(lambda x : extract_signature(x) )

# %% [markdown]
# # kunal[2][1]

# %%
a = 0;
for i in kunal :
    if i[1] == None :
        a += 1;
print(a)
# Out:
# 11186

# %%
text
# Out:
# 'Added dns conditional forwarders.\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n Hi Link,\r\n I can confirm Issue 4 has been resolved.\r\n Andy Ng\r\n Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com\r\n Andy Ng,\r\n Issue 4 has been fixed.\r\n Jesse,\r\n Could you let me know what the dns servers are for domains plhost.global, qaplhost.local and devplhost.content.local? This way I can add related dns conditional forwarders on LD DCs. Thanks.\r\n 10.51.1.12 us-plh-14.plhost.global\r\n 10.12.41.13 sc-qaplh-02v.qaplhost.local\r\n 10.12.42.11 cdev-plh-03v.devplhost.content.local\r\n Kind regards,\r\n Link Lee \r\n Information Technologies | Asia PAC\r\n Zhenhan.li@ivanti.com \r\n Tel: 8610-85153668 ext 226\r\n E-Fax:8610-85187107\r\n Fax:8610-85183135\r\n Hi Brett,\r\n Thanks for resolving issues 2 and 3 today.\r\n For issue 2, we are not able to access the Galway File Share: ie-fs-01v.lumension.lcl (10.5.10.13):\r\n For issue 3, we are not able to reach lum-prx.lumension.com on port 8088, and our EMSS agent is now Online: \r\n For issues 1 and 4, the internal DNS issues, we would wait for Jeremy or Link to add in the relevant DNS records when they are back.\r\n In the meantime, we are making do with adding the entries on the hosts file on our machines.\r\n Once again, thank you.\r\n Andy Ng\r\n Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com\r\n Hey Jeremy, I have been assisting the guys over in Singapore to get things up and running for their new office. Can you assist us with line items 1 and 4 below? Thanks\r\n Brett Erickson\r\n Sr. Network Engineer\r\n o 801-208-1555\r\n m 435-757-4706\r\n brett.erickson@ivanti.com\r\n www.ivanti.com\r\n Hi Brett,\r\n As Link is out of this office this leave, I am including you in this email.\r\n I have an update today. A small portion of the three mentioned issues are resolved. Please see my summary below.\r\n Ex-HEAT Content Search Tool not working \r\n As a workaround, we are able to get this working by adding these three lines in our hosts file on our machines:\r\n 10.51.1.12 us-plh-14.plhost.global\r\n 10.12.41.13 sc-qaplh-02v.qaplhost.local\r\n 10.12.42.11 cdev-plh-03v.devplhost.content.local\r\n Action required: please configure our two internal DNS servers, 172.27.0.250 and 172.28.0.250 to resolve the three FQDN highlighted in red above.\r\n Ex-HEAT file shares not working \r\n az-fs-03v.lumension.lcl (10.12.36.45) is working.\r\n ie-fs-01v.lumension.lcl (10.5.10.13) is still not working. See simple troubleshooting steps below. \r\n Ex-HEAT cannot connect to lum-prx.lumension.com port 8088 \r\n Still not working. See below. It can resolve, but cannot ping or reach the host on TCP port 8088.\r\n New issue found.\r\n Cannot resolve az.vpn.heatsoftware.com (38.92.192.66) and ie.vpn.heatsoftware.com (154.50.197.178) on our internal DNS servers, 172.27.0.250 and 172.28.0.250. As a workaround, we add these two lines in our hosts file:\r\n 38.92.192.66 az.vpn.heatsoftware.com \r\n 154.50.197.178 ie.vpn.heatsoftware.com\r\n Andy Ng\r\n Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com\r\n Hi Link,\r\n As requested, below is the list of connectivity issues we are facing on the network.\r\n Ex-HEAT Content Search Tool not working – For details and troubleshooting steps performed, see attached email ‘Unable to connect to Content Search Tool (10.19.0.93) on the new corporate network’. \r\n Summary: cannot reach az-engtools-01v.engdev.lumension.lcl (10.19.0.93) without connecting to Cisco VPN.\r\n Ex-HEAT file shares not working – For details and troubleshooting steps performed, see attached email ‘Cannot reach File Servers ie-fs-01v and az-fs-03 ...

# %%
signature
# Out:
# ' Technical Support Engineer\r\n o +65 6911 3879\r\n w  www.ivanti.com\r\n Note: My new email address is: andy.ng@ivanti.com'

# %%
signature_b

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
tagged = ne_chunk(pos_tag(word_tokenize(text)))
person = []
for subtree in tagged.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
            
print(person)
# Out:
# ['Link', 'Lee', 'Andy', 'Ng', 'Technical', 'Support', 'Engineer', 'Andy', 'Ng', 'Jesse', 'Link', 'Lee', 'Online', 'Jeremy', 'Link', 'Andy', 'Ng', 'Technical', 'Support', 'Engineer', 'Hey', 'Jeremy', 'Brett', 'Erickson', 'Network', 'Engineer', 'Link', 'Andy', 'Ng', 'Technical', 'Support', 'Engineer', 'Cisco', 'VPN', 'File', 'Servers', 'Cisco', 'VPN', 'Leonard', 'Andy', 'Ng']

# %%
from dill.source import getsource
print(getsource(signature))
# Out:
# """The package exploits machine learning for parsing message signatures.
#
# The public interface consists of only one `extract` function:
#
# >>> (body, signature) = extract(body, sender)
#
# Where body is the original message `body` and `sender` corresponds to a person
# who sent the message.
#
# When importing the package classifiers instances are loaded.
# So each process will have it's classifiers in memory.
#
# The import of the package and the call to the `extract` function are better be
# enclosed in a try-catch block in case they fail.
#
# .. warning:: When making changes to features or emails the classifier is
# trained against, don't forget to regenerate:
#
# * signature/data/train.data and
# * signature/data/classifier
# """
#
# from __future__ import absolute_import
# import os
#
# from . import extraction
# from . extraction import extract  #noqa
# from . learning import classifier
#
#
# DATA_DIR = os.path.join(os.path.dirname(__file__), 'data')
#
# EXTRACTOR_FILENAME = os.path.join(DATA_DIR, 'classifier')
# EXTRACTOR_DATA = os.path.join(DATA_DIR, 'train.data')
#
#
# def initialize():
#     extraction.EXTRACTOR = classifier.load(EXTRACTOR_FILENAME,
#                                            EXTRACTOR_DATA)
